# %% [markdown]
# # Lab 2: Bayesian PCA
#
# ### Machine Learning: Principles and Methods, November 2013
#
# * The lab exercises should be made in groups of three people, or at least two people.
# * The deadline is Wednesday, 11 December, 23:59.
# * Assignment should be sent to T.S.Cohen at uva dot nl (Taco Cohen). The subject line of your email should be "[MLPM2013] lab#_lastname1\_lastname2\_lastname3".
# * Put your and your teammates' names in the body of the email
# * Attach the .IPYNB (IPython Notebook) file containing your code and answers. Naming of the file follows the same rule as the subject line. For example, if the subject line is "[MLPM2013] lab01\_Kingma\_Hu", the attached file should be "lab01\_Kingma\_Hu.ipynb". Only use underscores ("\_") to connect names, otherwise the files cannot be parsed.
#
# Notes on implementation:
#
# * You should write your code and answers in an IPython Notebook: http://ipython.org/notebook.html. If you have problems, please contact us.
# * Among the first lines of your notebook should be "%pylab inline". This imports all required modules, and your plots will appear inline.
# * NOTE: test your code and make sure we can run your notebook / scripts!

# %% [markdown]
# ### Introduction
#
# In this lab assignment, we will implement a variational algorithm for Bayesian PCA. Unlike regular PCA based on maximization of retained variance or minimization of projection error (see Bishop, 12.1.1 and 12.1.2), probabilistic PCA defines a proper density model over observed and latent variables. We will work with a fully Bayesian model this time, which is to say that we will put priors on our parameters and will be interested in learning the posterior over those parameters. Bayesian methods are very elegant, but require a shift in mindset: we are no longer looking for a point estimate of the parameters (as in maximum likelihood or MAP), but for a full posterior distribution.
#
# The integrals involved in a Bayesian analysis are usually analytically intractable, so that we must resort to approximations. In this lab assignment, we will implement the variational method described in Bishop99. Chapters 10 and 12 of the PRML book contain additional material that may be useful when doing this exercise.
#
# * [Bishop99] Variational Principal Components, C. Bishop, ICANN 1999 - http://research.microsoft.com/pubs/67241/bishop-vpca-icann-99.pdf
#
# Below, you will find some code to get you started.

# %%
# %pylab inline
import scipy.special as sp

class BayesianPCA(object):
    
    def __init__(self, d, N, a_alpha=10e-3, b_alpha=10e-3, a_tau=10e-3, b_tau=10e-3, beta=10e-3):
        """
        """
        self.d = d # number of dimensions
        self.N = N # number of data points
        
        # Hyperparameters
        self.a_alpha = a_alpha
        self.b_alpha = b_alpha
        self.a_tau = a_tau
        self.b_tau = b_tau
        self.beta = beta

        # Variational parameters
        self.means_z = np.random.randn(d, N) # called x in bishop99
        self.sigma_z = np.random.randn(d, d)
        self.mean_mu = np.random.randn(d, 1)
        self.sigma_mu = np.random.randn(d, d)
        self.means_w = np.random.randn(d, d)
        self.sigma_w = np.random.randn(d, d)
        self.a_alpha_tilde = self.a_alpha + d/2.0
        self.bs_alpha_tilde = np.abs(np.random.randn(d, 1))
        self.a_tau_tilde = self.a_tau + (N*d)/2.0
        self.b_tau_tilde = np.abs(np.random.randn(1))
        
        #self.means_z = np.zeros((d, N)) + 1 # called x in bishop99
        #self.sigma_z = np.zeros((d, d)) + 1
        #self.mean_mu = np.zeros((d, 1)) + 1
        #self.sigma_mu = np.zeros((d, d)) + 1
        #self.means_w = np.zeros((d, d)) + 1
        #self.sigma_w = np.zeros((d, d)) + 1
        #self.a_alpha_tilde = self.a_alpha + d/2.0
        #self.bs_alpha_tilde = np.abs(np.zeros((d, 1))) + 1
        #self.a_tau_tilde = self.a_tau + (N*d)/2.0 
        #self.b_tau_tilde = np.abs(np.zeros(1)) + 1
    
    
    def update_z(self, X):
        #update sigma of z
        exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
        exp_WtW = np.zeros((d,d))
        for i in range(d):
            exp_WtW[:,i] = np.sum(self.sigma_w,1) + np.dot(self.means_w, self.means_w[:,i])
        self.sigma_z = numpy.linalg.inv(numpy.identity(d)+np.multiply(exp_tau, exp_WtW))
        
        
        #print 'sigma z:\n', self.sigma_z
        
        #Update means of z        
        exp_Wt = np.transpose(self.means_w)
        exp_mu = self.mean_mu
        
        #print 'shape exp Wt', exp_Wt.shape, 'shape exp_tau', exp_tau.shape
        #print 'shape sigma z', self.sigma_z.shape, 'shape exp mu', exp_mu.shape
        
        self.means_z = np.dot( np.dot( np.multiply(exp_tau, self.sigma_z), exp_Wt), (X-exp_mu) )
                
        #print 'means z:\n', self.means_z
    
    def update_mu(self, X):
        # Update sigma of mu        
        exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
        self.sigma_mu = np.multiply(1/float(self.beta+N*exp_tau), numpy.identity(d)) 
        
        #print 'sigma mu:\n', self.sigma_mu
        
        # Update means of mu        
        exp_W = self.means_w
        exp_z = self.means_z
        temp = numpy.sum(X-np.dot(exp_W, exp_z), 1)
        self.mean_mu[:,0] = np.dot(np.multiply(exp_tau, self.sigma_mu), temp)
        
        #print 'mean mu:\n', self.mean_mu
            
    def update_w(self, X):
        # Update sigma of W
        exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
        sum_exp_zzt = np.zeros((d,d))
        for i in range(d):
            exp_znznt = np.dot(self.means_z[i,:], np.transpose(self.means_z[i,:]))
            sum_exp_zzt = np.add(sum_exp_zzt, exp_znznt)
        exp_alpha = np.multiply(1/float(self.a_alpha_tilde), self.bs_alpha_tilde)
        exp_alpha = np.array(exp_alpha.conj().T).squeeze()        
        self.sigma_w = np.add(np.diag(exp_alpha), np.multiply(exp_tau, sum_exp_zzt))
        
        #print 'sigma w:\n', self.sigma_w#
        
        # Update mu of W
        # w(k) is a column
        for i in range(d):
            temp = X[i,:]-self.mean_mu[i] 
            repmat = np.tile(temp, (d,1))
            summation1 = np.sum(np.multiply(self.means_z, repmat),1)
            summation = np.tile(summation1, (1,1)).T
            if i == 0:
                print 'temp:\n', temp
                print 'summation:\n', summation1
            self.means_w[:,i] = (exp_tau*np.dot(self.sigma_w, summation))[:,0]
        
        #print 'means w:\n', self.means_w
        
    def update_alpha(self):
        # a_alpha_tilde is a constant: a_alpha + d/2 so set it in the initialization and do not change anymore
        
        b_temp = np.diag((np.trace(self.sigma_w)+np.dot(self.means_w.T, self.means_w))/2.0) + self.b_alpha
        self.bs_alpha_tilde = np.tile(b_temp, (1,1)).T
        
        #print 'a alpha tilde and bs alpha tilde:\n', self.a_alpha_tilde, '\n', self.bs_alpha_tilde
        
        #for i in range(d):
        #    print i
        #    temp = (np.trace(self.sigma_w)+np.dot(self.means_w[:,i].T, self.means_w[:,i]))/2.0
        #    self.bs_alpha_tilde[i] = self.b_alpha + temp
           
        
    def update_tau(self, X):
        # a_tau is a constant so set in the initialization
        
        exp_WtW = np.zeros((d,d))
        for i in range(d):
            exp_WtW[:,i] = np.sum(self.sigma_w,1) + np.dot(self.means_w, self.means_w[:,i])
        exp_mutmu = np.dot(self.mean_mu.T, self.mean_mu)        
        sum = 0.0
        
        for i in range(N):
            x_col = X[:,i]
            sum += np.dot(x_col.T, x_col) + exp_mutmu + np.trace(np.dot(exp_WtW, np.dot(x_col, x_col.T)))
            sum += 2.0 * np.dot(np.dot(self.mean_mu.T, self.means_w), self.means_z[:,i])
            sum -= 2.0 * np.dot(np.dot(x_col.T, self.means_w),self.means_z[:,i])
            sum -= 2.0 * np.dot(x_col.T, self.mean_mu)
                
        self.b_tau_tilde = self.b_tau + 0.5* sum
        
        #print 'a tau tilde and b tau tilde:\n', self.a_tau_tilde, '\n', self.b_tau_tilde
        
    def L(self, X):
        L = 0.0
        return L
    
    def fit(self, X, max_it):
        for i in range(max_it):
            if i%10 == 0:
                print i,
        
            self.update_alpha()
            self.update_tau(X)
            self.update_w(X)
            self.update_z(X)
            self.update_mu(X)
            
            print '\n w at',i, ':\n', self.means_w
            
            #if i%200==0:
            #    print '\n w at',i, ':\n', self.means_w
                
        print '\n w final:\n', self.means_w
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = 6
N = 100

pca = BayesianPCA(d, N)
X = np.random.randn(d, N)
for i in range(1):
    print '\n\n', i    
    pca.update_alpha()
    pca.update_tau(X)
    pca.update_w(X)
    pca.update_z(X)
    pca.update_mu(X)
# Out:
# 0
# temp:
# [ 0.56962174  0.09258291  0.70048175  1.68442144 -0.26370614 -1.07243125
#   0.48941376  0.55833086  1.66703944  0.76767358  1.01044992  0.20945746
#   0.41847137  0.52782811  1.05338295  0.07513515  0.85534484  0.66196029
#   0.2858824   0.69387871  1.06735989 -0.50751837  0.17985141  1.42695152
#   1.04633859  1.3483951   3.16769749 -0.82381435  0.2182708  -1.24063461
#   2.1466034   0.54074629  1.19575829  1.65824934 -1.25314036 -0.51027285
#   1.04929868  0.32307742  0.08940202 -0.00486062 -0.48797854  1.87370267
#  -0.41056884  2.69374398  0.08994487 -0.10498303  0.66165329  0.82497873
#   0.82107768 -0.11458249  0.28992552  0.32365947  0.45633056  2.46101545
#   0.06271884  0.19994795  2.44953646  1.15422658  0.14770775  2.73703415
#   2.52973559  1.48028651 -1.07776584  0.65832224 -0.82470812 -2.06840806
#   1.23504432  0.77279661  3.70226568  0.43603006  1.41712706  0.85068568
#   0.72744099  0.49968895  1.20206462  1.0316974  -0.59646677  0.53247874
#  -0.4916027   0.67757144  0.17100114  0.12905318 -0.16731285  1.59477059
#  -0.70222299  0.22761925 -0.39710119  0.02786372 -0.16076169 -0.78753257
#   1.84641223 -0.64469167  1.04735461  0.74341636 -0.01323607  1.72024216
#   1.15689286 -0.24382592  0.11761775  2.16037106]
# summation:
# [ 13.19429086 -20.78294194  -8.30236495 -11.15421722  -6.99433536
#   11.0633146 ]

# %%
from IPython.display import display, Math, Latex

# %% [markdown]
# ### 1. The Q-distribution (5 points)
#
# In variational Bayes, we introduce a distribution $Q(\Theta)$ over parameters / latent variables in order to make inference tractable. We can think of $Q$ as being an approximation of a certain distribution. What function does $Q$ approximate, $p(D|\Theta)$, $p(\Theta|D)$, $p(D, \Theta)$, $p(\Theta)$, or $p(D)$, and how do you see that?

# %% [markdown]
# The function $Q$ approximates the function that is the posterior distribution, $p(\Theta | D) $.
#
# The posterior $P(\Theta | D)$ is given by multiplying the likelihood by the prior and then normalizing:
#
# \begin{align}
# P(\Theta | D) &= \dfrac{P(D | \Theta)P( \Theta)}{P(D)} \\
#               &= \dfrac{P(D | \Theta)P( \Theta)}{\int P(D | \Theta)P(\Theta) \hspace{1mm} d\Theta}
# \end{align}
#
# Why is this useful?
# For Maximum a Posteriori (MAP) learning, we could use the posterior to get a point estimate of the parameters:
#
# \begin{align}
# \widetilde{\Theta}_{\text{MAP}}(D)&= \arg\max_{\Theta} P(\Theta | D) \\
#             & \propto {P(D | \Theta)P( \Theta)}
# \end{align}
#
# So for MAP learning the normalization (and therefore integration) is not needed. Like Maximum likelihood estimation (MLE) learning, MAP learning learns a point estimate of our parameters.
#
# In the Bayesian framework no fixed parameter setting is chosen. The posterior is used to obtain a predictive density (also called the posterior predictive distribution) for a new data point $t^{*}$ with:
#
# \begin{align}
# P(t^{*} | D) &= \int P(t^{*} | \Theta) P(\Theta | D) \hspace{2mm} d\Theta
# \end{align}
#
# This means that in the Bayesian learning framework we consider all possible parametrizations of our models by incorporating the posterior this way. Each of these is weighted by the evidence for them in $D$.
# (Note that when predicting, we also return a probability distribution as prediction for $t^{*}$.
# Retaining all possible parametrizations is in this case of Principal Component Analysis) particularly advantageous for automatically determining an adequate number of principal components given $D$.
#
# Note that we need to integrate over all possible parametrizations for this. In practice this can quickly become infeasible for models with many parameters; when using a mixture of models; or when the prior distribution is not of the same functional form as the likelihood distribution. Therefore we use a ''simpler'' distribution $Q(\Theta)$ to approximate $P(\Theta|D)$.

# %% [markdown]
# ### 2. The mean-field approximation (15 points)
#
# Equation 13 from [Bishop99] is a very powerful result: assuming only that $Q(\Theta)$ factorizes in a certain way (no assumptions on the functional form of the factors $Q_i$!), we get a set of coupled equations for the $Q_i$.
#
# However, the expression given in eq. 13 for Q_i contains a small mistake. Starting with the expression for the lower bound $\mathcal{L}(Q)$, derive the correct expression (and include your derivation). You can proceed as follows: first, substitute the factorization of $Q$ (eq. 12) into the definition of $\mathcal{L}(Q)$ and separate $\mathcal{L}(Q)$ into $Q_i$-dependent and $Q_i$-independent terms. At this point, you should be able to spot the expectations $\langle\cdot\rangle_{k \neq i}$ over the other $Q$-distributions that appear in Bishop's solution (eq. 13). Now, keeping all $Q_k, k \neq i$ fixed, maximize the expression with respect to $Q_i$. You should be able to spot the form of the optimal $ln Q_i$, from which $Q_i$ can easily be obtained.

# %% [markdown]
# It is given that the lower bound is
#
# $$
# \begin{align}
# \mathcal{L}(Q) =& \int Q(\Theta) \log \dfrac{P(D, \Theta)}{Q(\Theta)}
#                 \hspace{3mm} d \Theta  \\
# \end{align}
# $$
#
# And the factorization is
#
# \begin{equation}
# Q(\Theta)= \prod_{k} Q_k(\Theta_k)
# \end{equation}
#
# Plugging in the factorization into the lower bound, we get
#
# \begin{align}
# \mathcal{L}(Q) =&  \int
#                      \prod_{k} Q_k( \Theta_k)
#                      \left[
#                          \log P(D,\Theta) - \log \left( \prod_k Q_k(\Theta_k) \right)
#                      \right]
#                  \hspace{3mm} d \Theta  \\
#               =& \int
#               \prod_{k} Q_k( \Theta_k)
#                      \left[
#                          \log P(D,\Theta) - \sum_k \log Q_k(\Theta_k)
#                      \right]
#                   \hspace{3mm} d \Theta
# \end{align}
#
# By denoting a specific factor $Q_i$ separately we arrive at
#
# \begin{align}
# \mathcal{L}(Q) =& \int Q_i( \Theta_i) \prod_{k \neq i} Q_k( \Theta_k)
#                 \left[ \log P(D, \Theta) - \log \left( \prod_{j \neq i}  Q_j(\Theta_j) \right) - \log Q_i (\Theta_i) \right]
#                 \hspace{3mm} d \Theta
# \end{align}
#
# By taking the integral of $Q_i$ apart from those for $\{Q_1, \dots ,Q_{i-1},Q_{i+1}, \dots ,Q_M \}$, we get
#
# \begin{align}
# \mathcal{L}(Q) =&
#     \int Q_i(\Theta_i)
#         \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k) \log P(D, \Theta)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#     \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k)
#             \log \left( \prod_{j \neq i} Q_j(\Theta_j) \right)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}  \hspace{3mm} - \\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#             \int
#              \prod_{k \neq i} Q_k( \Theta_k)
#              \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}
# \end{align}

# %% [markdown]
# Now, when we keep the $Q_k \neq Q_{i}$ fixed the following happens, the integral over $\Theta_{\setminus i}$  in the third row of the equation for $\mathcal{L}(Q)$ will become 1, because all $Q_n(\Theta_n)$ are probability distributions.
#
# \begin{align}
# \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#             \int
#              \prod_{k \neq i} Q_k( \Theta_k)
#              \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}
#         =&
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#         \prod_{k \neq i}
#             \int
#               Q_k( \Theta_k)
#              \hspace{3mm} d \Theta_{k}
#         \right]
#         \hspace{3mm} d \Theta_{i} \\
#      =&
#       \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#         \prod_{k \neq i}
#             1
#         \right]
#         \hspace{3mm} d \Theta_{i}
# \end{align}
#
# So we can rewrite the equation as
#
# \begin{align}
# \mathcal{L}(Q)  =&
#     \int Q_i(\Theta_i)
#         \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k) \log P(D, \Theta)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#     \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k)
#             \log \left( \prod_{j \neq i} Q_j(\Theta_j) \right)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}  \hspace{3mm} - \\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \hspace{3mm} d \Theta_{i}
# \end{align}
#
#
# Furthermore, when we keep the $Q_k \neq Q_{i}$ fixed, the $\Theta_{\setminus i}$ integral in the second row of the equation for  $\mathcal{L}(Q)$ will become a constant. We know that $\int Q_i(\Theta_i)  d\Theta_{i}$ should be 1 because $Q_i$ is a probability distribution. So the whole second row can be viewed as a constant.
#
#
# \begin{align}
# \mathcal{L}(Q)  =&
#     \int Q_i(\Theta_i)
#         \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k) \log P(D, \Theta)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \hspace{3mm} d \Theta_{i}  \hspace{1mm} + \text{const}
# \end{align}

# %% [markdown]
# Note that the integral over $\Theta_{\setminus i}$  in the  first line in $\mathcal{L}(Q)$ could be rewritten as an expectation :
#
# \begin{align}
# \mathcal{L}(Q)  =&
#     \int Q_i(\Theta_i) \cdot
#         \mathbb{E}_{[k \neq i]}[ \log P(D, \Theta)]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \hspace{3mm} d \Theta_{i}  \hspace{1mm} + \text{const}
# \end{align}
#
# Where $\mathbb{E}_{[k \neq i]}$ denotes this expected value is with respect to the $Q$ distributions over all variables $\Theta_k \neq \Theta_i$.
#
#
# We can define $\mathbb{E}_{[k \neq i]}[ \log P(D, \Theta)]$ as $\log \widetilde{P}(D, \Theta_i)$.
#
# Intuitively it makes sense to see  $\log \widetilde{P}(D, \Theta_i)$, the joint probability of that parameter and the data, as the expectation of $\log P(D, \Theta)$ under all $\Theta_k$ that are not $\Theta_i$ , i.e., to not marginalize out  $\Theta_i$ in $\log P(D, \Theta)$.
# It is here particularly useful to be able to rewrite the above equation as:
#
# \begin{align}
# \mathcal{L}(Q)  =&  \int Q_i(\Theta_i) \log \widetilde{P}(D, \Theta_i) -  \int Q_i(\Theta_i) \log Q_i(\Theta_i) \\
#                 =& \int Q_i(\Theta_i) \log \dfrac{\widetilde{P}(D , \Theta_i)}{ Q_i(\Theta_i)} \\
#                 =& - \text{KL} \left(Q_i(\Theta_i) || \widetilde{P}(D, \Theta_i) \right)
# \end{align}
#
# Recall we wanted to maximize the lower bound function $\mathcal{L}(Q)$. We see that this negative KL-divergence will be maximal when
#
# \begin{align}
#  Q_i(\Theta_i) &= \widetilde{P}(D, \Theta_i)  \\
#  \log  Q_i(\Theta_i) &= \log \widetilde{P}(D, \Theta_i)  \\
#                      &= \mathbb{E}_{[k \neq i]}[\log P(D, \Theta)]\\
#  Q_i(\Theta_i)      &= \exp \left( \mathbb{E}_{[k \neq i]} [\log P(D, \Theta)] \right)
# \end{align}
#
# So in line with Bishop (except a subscript mismatch on his side), accounting for normalization (marginalizing over all $\Theta_{\setminus i}$) we get that the optimal value for $Q_i$ is
#
# \begin{align}
#  Q_i^{*}(\Theta_i)      &= \dfrac{\exp ( \mathbb{E}_{[k \neq i]} [\log P(D, \Theta)] )   }
#                       {\int \exp ( \mathbb{E}_{[k \neq i]} [\log P(D, \Theta)] ) \hspace{2mm} d\Theta_i  }
# \end{align}

# %% [markdown]
# ### 3. The log-probability (10 points)
#
# Write down the log-prob of data and parameters, $\ln p(\mathbf{X}, \mathbf{Z}, \mathbf{W}, \mathbf{\alpha}, \tau, \mathbf{\mu})$, in full detail (where $\mathbf{X}$ are observed, $\mathbf{Z}$ is latent; this is different from [Bishop99] who uses $\mathbf{T}$ and $\mathbf{X}$ respectively, but $\mathbf{X}$ and $\mathbf{Z}$ are consistent with the PRML book and are more common nowadays). Could we use this to assess the convergence of the variational Bayesian PCA algorithm? If yes, how? If no, why not?

# %% [markdown]
# The log-probability of the data and parameters is defined as:
# $$
# \begin{align}
# \ln p ( X, Z, W, \alpha, \tau, \mu) =&
# \ln \left(  \prod_{n=1}^N p(x_n| z_n, W, \mu, \tau)p(Z)p(W|\alpha)p(\alpha)p(\mu)p(\tau) \right) \\
# =& \ln \left( \prod_{n=1}^N \left[ \left( \frac{\tau}{2 \pi} \right) ^{D/2} \exp \left( - \frac{\tau}{2} \parallel x_t-Wz_n-\mu \parallel ^2  \right) \right]
# \prod_{n=1}^N \left[  \left( \frac{1}{2 \pi} \right)^{q/2} \exp \left( - \frac{1}{2} z_n^\top z_n \right) \right] \\
# \prod_{i=1}^q \left[ \left( \frac{\alpha_i}{2 \pi} \right)^{D/2} \exp \left( -\frac{\alpha_i}{2}  w_i^\top w_i \right) \right]
# \prod_{i=1}^q \left[ \frac{1}{\Gamma(a_\alpha)} b_\alpha^{a_\alpha} \alpha_i^{a_\alpha-1} e^{-b_\alpha \: \alpha_i} \right]\\
# \left[ \left(\frac{ \beta}{2\pi} \right)^{D/2} \exp \left( - \frac{\beta}{2} \mu^\top \mu \right) \right]
# \left[ \frac{1}{\Gamma(c_\tau)} d_\tau^{c_\tau} \tau^{c_\tau-1} e^{-d_\tau \: \tau} \right] \right)
# \\
# =& \frac{ND}{2} \ln \frac{\tau}{2 \pi} + \sum_{n=1}^N \left[ - \frac{\tau}{2} \parallel x_n-Wz_n-\mu \parallel ^2 \right]
# + \frac{Nq}{2} \ln \frac{1}{2 \pi} + \sum_{n=1}^N \left[ - \frac{1}{2} z_n^\top z_n \right] \\
# &+ \sum_{i=1}^q \left[ \frac{D}{2} \ln \frac{\alpha_i}{2 \pi} \right] + \sum_{i=1}^q \left[ - \frac{\alpha_i}{2} w_i^\top w_i \right]
# + \: q \ln \frac{ b_\alpha^{a_\alpha}}{\Gamma(a_\alpha)} + \sum_{i=1}^q \left[ (a_\alpha -1) \ln \alpha_i - b_\alpha \alpha_i \right] \\
# &+ \frac{D}{2} \ln \frac{\beta}{2 \pi} - \frac{\beta}{2} \mu^\top\mu - \ln \Gamma(c_\tau) + \ln d_\tau^{c_\tau} + (c_\tau-1)\ln \tau - d_\tau \tau
# \end{align}
# $$

# %% [markdown]
# Bayesian learning results in a posterior distribution over the parameters. If we wish to use $\ln P(\Theta,D)$ to assess convergence we have no choice but to use some point estimate of the parameters from the approximated posterior $Q$ to evaluate  $\ln P(\Theta,D)$ (we cannot plug in the distribution). However, we consider convergence as $Q$ being as similar to the real posterior $P(\Theta|D)$ as possible. There is no guarantee that if $Q$ becomes more similar to $P(\Theta|D)$, that the used point estimate of $Q$ results in a higher value when evaluating $\ln P(\Theta,D)$. Therefore $\ln P(\Theta,D)$ is not a suitable option to assess convergence.

# %% [markdown]
# ### 4. The lower bound $\mathcal{L}(Q)$ (25 points)
#
# Derive an expression for the lower bound $\mathcal{L}(Q)$ of the log-prob $\ln p(X)$ for Bayesian PCA, making use of the factorization (eq. 12) and the form of the Q-distributions (eq. 16-20) as listed in [Bishop99]. Show your steps. Implement this function.
#
# The following result may be useful:
#
# For $x \sim \Gamma(a,b)$, we have $\langle \ln x\rangle = \ln b + \psi(a)$, where $\psi(a) = \frac{\Gamma'(a)}{\Gamma(a)}$ is the digamma function (which is implemented in numpy.special).

# %% [markdown]
# \begin{align}
# \mathcal{L}(Q) =& \int Q(\Theta) \ln \dfrac{P(D,\Theta)}{Q(\Theta)} \hspace{2mm} d \Theta\\
#                 =& \int Q(\Theta) \ln P(D,\Theta) \hspace{2mm} d \Theta  - \int Q(\Theta) \ln Q(\Theta)  \hspace{2mm} d \Theta\\
#                 =& \mathbb{E}_Q[ \ln P(D,\Theta)] - \mathbb{E}_q[\ln Q(\Theta)]\\
#                =& \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N} (x_n | m_x^{(n)} \Sigma_x) \right) \right]
#                 + \mathbb{E}_Q \left[ \ln P(X) \right ] + \mathbb{E}_Q \left[\ln  P(W | \alpha ) \right]
#                 + \mathbb{E}_Q \left[ \ln P(\alpha) \right] + \mathbb{E}_Q \left[ \ln P(\mu) \right]
#                 + \mathbb{E}_Q \left[ \ln P(\tau) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln Q(X) \right] - \mathbb{E}_Q \left[ \ln Q(W) \right] - \mathbb{E}_Q \left[ Q(\alpha) \right] - \mathbb{E}_Q \left[ \ln Q(\mu) \right] - \mathbb{E}_Q \left[ \ln \left( Q(\tau) \right) \right]\\
#                 =& \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N}({t}|{W} {x}_i + \mu , \sigma^2 I_d) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N}(x|0, I_q) \right) \right]              \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \prod_{i=1}^{q} (\dfrac{\alpha_i}{2 \pi})^{d/2}  \exp( - \dfrac{1}{2} \alpha_i ||w_i||^2 ) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \prod_{i=1}^{q} \Gamma ( \alpha_i| a_{\alpha}, b_{\alpha}) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \mathcal{N}(\mu|0, \beta^{-1} I) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \Gamma(\tau|c_\tau, d_\tau ) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N}(x_n| m_x^{(n)}, \Sigma_x) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \prod_{k=1}^{d}  \mathcal{N}(\widetilde{w}_k | m_w^{(k)}, \Sigma_w) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \prod_{i=1}^{q} \Gamma(\alpha_i| \widetilde{a}_\alpha, \widetilde{b}_{\alpha i} ) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \mathcal{N}(\mu | m_\mu, \Sigma_\mu) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \Gamma(\tau | \widetilde{a}_\tau, \widetilde{b}_\tau ) \right) \right]
# \end{align}

# %% [markdown]
# ### 5. Optimize variational parameters (50 points)
# Implement the update equations for the Q-distributions, in the __update_XXX methods. Each update function should re-estimate the variational parameters of the Q-distribution corresponding to one group of variables (i.e. either $Z$, $\mu$, $W$, $\alpha$ or $\tau$).

# %% [markdown]
# ### 6. Learning algorithm (10 points)
# Implement the learning algorithm described in [Bishop99], i.e. iteratively optimize each of the Q-distributions holding the others fixed.
#
# What would be a good way to track convergence of the algorithm? Implement your suggestion.
#
# Test the algorithm on some test data drawn from a Gaussian with different variances in orthogonal directions.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_data(X):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X[0,:], X[1,:], zs=X[2,:])

# %% [markdown]
# We created a set of orthonormal basis vectors by using Matlab code from <a href="http://www.mathworks.com/matlabcentral/fileexchange/18973-create-orthonormal-vectors">[Price 2008]</a>.

# %%
# matrix with orthonormal vectors
A = np.array([ [0.4246,-0.1753,-0.1466,-0.0956,0.7864,0.3741]
                ,[0.5199,0.3483,0.2280,-0.4751,-0.4102,0.4031]
                ,[-0.2212,-0.7183,-0.2838,-0.2656,-0.3263,0.4213]
                ,[-0.5600,0.0724,0.6716,-0.1030,0.2397,0.4025]
                ,[0.2692,-0.1393,0.2114,0.8147,-0.2223,0.3876]
                ,[-0.3382,0.5544,-0.5918,0.1422,-0.0037,0.4558]])

# eigenvalues on a diagonal matrix representing the magnitude of the variance
L = np.diag( [7,6,5,4,1,1])

# Covariance matrix generated based on A and L
covariance = np.dot(np.dot(A, L) , A.T)
means = [2,2,2,2,2,2]

dims = 6
N = 100

data = numpy.random.multivariate_normal(means, covariance, (N)).T

#print 'Plot of the first three dimensions of the data'
#plot_data(data)

bay_pca = BayesianPCA(dims,N)
bay_pca.fit(data, 10)
# Out:
# 0 temp:
# [-0.32785593  1.63976677  0.67443901 -0.40875615 -1.69391144  1.65725501
#   0.73702763  2.21830635  0.15976032 -0.20934248  3.62601491  0.51515861
#   1.09521277  2.16704547  1.8559758   0.18468785  3.31982855 -2.3080683
#  -0.42636733  3.39217919 -1.15238265  1.70099079  1.57851795  1.84072947
#   2.61569314  1.01696846  2.12632819  1.55006384 -1.85683633  0.49468351
#  -0.70317415  0.18130139  2.93240601 -1.2620898   5.64623203 -0.85387367
#   0.91552763 -1.16966175  2.85947855  2.10176182  0.33037609  4.70925029
#  -0.53592963  0.2374541   3.17706755  2.54667268 -0.86262092  0.15761403
#  -0.33746495  1.0995534   1.47878138  1.60560212  0.17632557  2.22169158
#  -2.09412791  2.68019814  0.93975189  1.53212504 -0.13142233  1.72381314
#   1.25147075  2.95710029  1.73040872  3.45151196  2.25001311 -0.91472743
#  -0.45735677  1.52785917  3.14631613 -0.30197131  3.47141357  2.16179851
#   1.76370623  1.03465084  1.12820845  1.59443868  1.98199684  0.7547427
#   0.94111057  1.27937067  3.31664809  2.11351099  3.52652681  0.45244364
#   1.74822069  1.08809146  0.23069318  1.65631622  1.52628967  0.61768427
#  -1.57037899  2.19740348  2.06674768  0.72482935  0.64162932  0.82513581
#   5.22831697 -0.96620217  3.17663312  1.24874379]
# summation:
# [-22.48940194  11.95509412 -16.69411149 -36.79683854  10.83928251
#  -27.50879591]
#
#  w at 0 :
# [[-29.49649002 -15.92681517 -22.36169605 -20.1446967  -14.31250184
#   -32.24538611]
#  [-28.8644149  -15.69276055 -23.00157785 -20.39522501 -14.35453783
#   -30.73946211]
#  [-30.15508743 -16.85471586 -23.04080457 -21.59359003 -14.68806622
#   -34.93900053]
#  [-29.89900842 -15.5560432  -22.99370139 -19.97944441 -15.30031111
#   -31.20650421]
#  [-28.68205975 -15.80325895 -22.64132335 -22.16943968 -15.88377578
#   -36.99570497]
#  [-29.63524634 -15.59974042 -22.46751671 -19.82057377 -14.62423647
#   -30.91372396]]
# temp:
# [ 3.52995014  5.49757285  4.53224509  3.44904993  2.16389464  5.51506109
#   4.59483371  6.07611243  4.0175664   3.6484636   7.48382099  4.37296469
#   4.95301884  6.02485155  5.71378188  4.04249393  7.17763463  1.54973778
#   3.43143875  7.24998527  2.70542343  5.55879687  5.43632402  5.69853555
#   6.47349922  4.87477453  5.98413427  5.40786991  2.00096975  4.35248959
#   3.15463193  4.03910747  6.79021209  2.59571628  9.50403811  3.00393241
#   4.7733337   2.68814432  6.71728463  5.9595679   4.18818217  8.56705637
#   3.32187645  4.09526017  7.03487363  6.40447876  2.99518516  4.0154201
#   3.52034112  4.95735948  5.33658745  5.46340819  4.03413165  6.07949766
#   1.76367817  6.53800421  4.79755797  5.38993112  3.72638375  5.58161921
#   5.10927683  6.81490637  5.5882148   7.30931803  6.10781919  2.94307865
#   3.40044931  5.38566524  7.0041222   3.55583477  7.32921964  6.01960459
#   5.6215123   4.89245692  4.98601452  5.45224476  5.83980291  4.61254877
#   4.79891664  5.13717675  7.17445417  5.97131707  7.38433288  4.31024971
#   5.60602677  4.94589753  4.08849926  5.5141223   5.38409575  4.47549035
#   2.28742709  6.05520956  5.92455376  4.58263543  4.4994354   4.68294189
#   9.08612305  2.89160391  7.03443919  5.10654987]
# summation:
# [ -744.9361727   1069.17522817   353.91117336   604.43114782  1477.586467
#  -1206.86158143]
#
#  w at 1 :
# [[ -4.02210992  -0.26287872  -5.62899046  -0.8944395   -6.34147556
#    -1.92889535]
#  [  1.75773171   0.10618005   2.4458722    0.3568133    2.81467949
#     0.79216681]
#  [  1.15383494   0.04803614   1.61788845   0.215187     1.84866896
#     0.49919231]
#  [  1.6415028    0.0908902    2.29619771   0.34304427   2.61421286
#     0.75013661]
#  [  2.13995315   0.13736602   2.9848765    0.42012803   3.38915653
#     0.95824077]
#  [ -8.10913519  -0.44082804 -11.3001171   -1.51491379 -12.99333133
#    -3.49621495]]
# temp:
# [  3.88302766e-03   1.97150573e+00   1.00617797e+00  -7.70171902e-02
#   -1.36217248e+00   1.98899398e+00   1.06876660e+00   2.55004531e+00
#    4.91499283e-01   1.22396480e-01   3.95775387e+00   8.46897570e-01
#    1.42695173e+00   2.49878444e+00   2.18771477e+00   5.16426811e-01
#    3.65156751e+00  -1.97632934e+00  -9.46283676e-02   3.72391815e+00
#   -8.20643690e-01   2.03272975e+00   1.91025691e+00   2.17246844e+00
#    2.94743211e+00   1.34870742e+00   2.45806716e+00   1.88180280e+00
#   -1.52509737e+00   8.26422473e-01  -3.71435189e-01   5.13040351e-01
#    3.26414497e+00  -9.30350840e-01   5.97797100e+00  -5.22134710e-01
#    1.24726659e+00  -8.37922793e-01   3.19121751e+00   2.43350078e+00
#    6.62115057e-01   5.04098925e+00  -2.04190665e-01   5.69193058e-01
#    3.50880652e+00   2.87841165e+00  -5.30881957e-01   4.89352988e-01
#   -5.72599201e-03   1.43129236e+00   1.81052034e+00   1.93734108e+00
#    5.08064536e-01   2.55343054e+00  -1.76238895e+00   3.01193710e+00
#    1.27149085e+00   1.86386401e+00   2.00316637e-01   2.05555210e+00
#    1.58320971e+00   3.28883925e+00   2.06214768e+00   3.78325092e+00
#    2.58175207e+00  -5.82988463e-01  -1.25617808e-01   1.85959813e+00
#    3.47805509e+00   2.97676517e-02   3.80315253e+00   2.49353747e+00
#    2.09544519e+00   1.36638980e+00   1.45994741e+00   1.92617764e+00
#    2.31373580e+00   1.08648166e+00   1.27284953e+00   1.61110963e+00
#    3.64838705e+00   2.44524995e+00   3.85826577e+00   7.84182598e-01
#    2.07995966e+00   1.41983042e+00   5.62432147e-01   1.98805518e+00
#    1.85802863e+00   9.49423235e-01  -1.23864003e+00   2.52914244e+00
#    2.39848664e+00   1.05656831e+00   9.73368285e-01   1.15687477e+00
#    5.56005593e+00  -6.34463207e-01   3.50837208e+00   1.58048275e+00]
# summation:
# [-0.0110467  -0.0007311  -0.01569215 -0.00269614 -0.01776389 -0.00542846]
#
#  w at 2 :
# [[ -2.19498560e-04  -1.80575183e-04  -9.58384027e-05  -2.44060375e-04
#    -1.44618230e-04  -7.58477194e-04]
#  [ -1.41451853e-05  -1.13552658e-05  -9.29554120e-06  -1.51607196e-05
#    -9.83815540e-06  -3.89943805e-05]
#  [ -3.19579713e-04  -2.63009503e-04  -1.39057624e-04  -3.53299186e-04
#    -2.10506000e-04  -1.09981900e-03]
#  [ -5.22133102e-05  -4.27058386e-05  -2.99376037e-05  -5.28316265e-05
#    -3.86217470e-05  -1.44141374e-04]
#  [ -3.67393564e-04  -3.02431760e-04  -1.58141130e-04  -4.13338009e-04
#    -2.42655847e-04  -1.28827305e-03]
#  [ -1.05575025e-04  -8.64456949e-05  -5.46772642e-05  -1.10297653e-04
#    -7.40930670e-05  -3.18851455e-04]]
# temp:
# [-0.31135837  1.65626434  0.69093658 -0.39225858 -1.67741387  1.67375258
#   0.7535252   2.23480392  0.17625789 -0.19284491  3.64251248  0.53165618
#   1.11171033  2.18354304  1.87247337  0.20118542  3.33632612 -2.29157073
#  -0.40986976  3.40867676 -1.13588508  1.71748836  1.59501552  1.85722704
#   2.63219071  1.03346603  2.14282576  1.5665614  -1.84033876  0.51118108
#  -0.68667658  0.19779896  2.94890358 -1.24559223  5.6627296  -0.8373761
#   0.9320252  -1.15316419  2.87597612  2.11825939  0.34687366  4.72574786
#  -0.51943206  0.25395166  3.19356512  2.56317025 -0.84612335  0.17411159
#  -0.32096739  1.11605097  1.49527895  1.62209968  0.19282314  2.23818915
#  -2.07763034  2.6966957   0.95624946  1.54862261 -0.11492476  1.7403107
#   1.26796832  2.97359786  1.74690629  3.46800953  2.26651068 -0.89822986
#  -0.4408592   1.54435673  3.16281369 -0.28547374  3.48791114  2.17829608
#   1.7802038   1.05114841  1.14470601  1.61093625  1.99849441  0.77124026
#   0.95760813  1.29586824  3.33314566  2.13000856  3.54302437  0.46894121
#   1.76471826  1.10458903  0.24719075  1.67281379  1.54278724  0.63418184
#  -1.55388142  2.21390105  2.08324525  0.74132692  0.65812689  0.84163338
#   5.24481454 -0.9497046   3.19313068  1.26524136]
# summation:
# [ -9.45417893e-06  -7.55669102e-06  -3.34854453e-06  -1.06828051e-05
#   -5.72614835e-06  -3.59464051e-05]
#
#  w at 3 :
# [[ -1.83253583e-07  -1.29998913e-07  -2.45130744e-07  -1.99911556e-07
#    -2.61940225e-07  -1.69349243e-07]
#  [ -1.46473926e-07  -1.03805275e-07  -1.95978315e-07  -1.59668007e-07
#    -2.09386805e-07  -1.35185746e-07]
#  [ -6.49059836e-08  -4.80458077e-08  -8.73278861e-08  -7.66947020e-08
#    -9.29206055e-08  -6.61010145e-08]
#  [ -2.07068463e-07  -1.45969733e-07  -2.75438811e-07  -2.21220689e-07
#    -2.96424394e-07  -1.86665128e-07]
#  [ -1.10991892e-07  -7.95478974e-08  -1.48854017e-07  -1.24537737e-07
#    -1.59193123e-07  -1.05920326e-07]
#  [ -6.96761462e-07  -4.85872443e-07  -9.26057863e-07  -7.28923792e-07
#    -9.96348581e-07  -6.12023266e-07]]
# temp:
# [-0.30518255  1.66244016  0.6971124  -0.38608276 -1.67123805  1.6799284
#   0.75970102  2.24097974  0.18243371 -0.18666909  3.6486883   0.537832
#   1.11788615  2.18971886  1.87864919  0.20736124  3.34250194 -2.28539491
#  -0.40369394  3.41485258 -1.12970926  1.72366418  1.60119133  1.86340286
#   2.63836653  1.03964184  2.14900158  1.57273722 -1.83416294  0.5173569
#  -0.68050076  0.20397478  2.9550794  -1.23941641  5.66890542 -0.83120028
#   0.93820101 -1.14698837  2.88215194  2.12443521  0.35304948  4.73192368
#  -0.51325624  0.26012748  3.19974094  2.56934607 -0.83994753  0.18028741
#  -0.31479157  1.12222679  1.50145476  1.6282755   0.19899896  2.24436497
#  -2.07145452  2.70287152  0.96242528  1.55479843 -0.10874894  1.74648652
#   1.27414414  2.97977368  1.75308211  3.47418535  2.2726865  -0.89205404
#  -0.43468338  1.55053255  3.16898951 -0.27929792  3.49408695  2.1844719
#   1.78637961  1.05732423  1.15088183  1.61711207  2.00467022  0.77741608
#   0.96378395  1.30204406  3.33932148  2.13618438  3.54920019  0.47511702
#   1.77089408  1.11076484  0.25336657  1.67898961  1.54896306  0.64035766
#  -1.5477056   2.22007687  2.08942107  0.74750274  0.66430271  0.8478092
#   5.25099036 -0.94352878  3.1993065   1.27141718]
# summation:
# [ -6.81286083e-09  -4.57277837e-09  -9.38963070e-09  -7.46934614e-09
#   -1.01169700e-08  -6.18699667e-09]
#
#  w at 4 :
# [[ -1.32055805e-10  -1.62653969e-10  -1.38646558e-10  -2.96763187e-10
#    -1.87181842e-10  -3.95433020e-10]
#  [ -8.86355887e-11  -1.08618314e-10  -9.35266490e-11  -1.97538428e-10
#    -1.25389608e-10  -2.61912355e-10]
#  [ -1.82002139e-10  -2.23847445e-10  -1.91034549e-10  -4.07329460e-10
#    -2.57712846e-10  -5.42360516e-10]
#  [ -1.44780665e-10  -1.76304607e-10  -1.53100381e-10  -3.18234452e-10
#    -2.04297800e-10  -4.19852958e-10]
#  [ -1.96100384e-10  -2.41454749e-10  -2.05986563e-10  -4.40650911e-10
#    -2.78078677e-10  -5.86851822e-10]
#  [ -1.19924485e-10  -1.45660237e-10  -1.27077606e-10  -2.62362866e-10
#    -1.69025971e-10  -3.45297356e-10]]
# temp:
# [-0.30618858  1.66143413  0.69610636 -0.3870888  -1.67224408  1.67892237
#   0.75869499  2.23997371  0.18142768 -0.18767513  3.64768226  0.53682596
#   1.11688012  2.18871283  1.87764316  0.2063552   3.34149591 -2.28640094
#  -0.40469997  3.41384655 -1.1307153   1.72265815  1.6001853   1.86239683
#   2.6373605   1.03863581  2.14799555  1.57173119 -1.83516897  0.51635087
#  -0.6815068   0.20296874  2.95407336 -1.24042245  5.66789939 -0.83220632
#   0.93719498 -1.1479944   2.88114591  2.12342917  0.35204345  4.73091764
#  -0.51426227  0.25912145  3.19873491  2.56834004 -0.84095356  0.17928138
#  -0.3157976   1.12122075  1.50044873  1.62726947  0.19799293  2.24335894
#  -2.07246055  2.70186549  0.96141925  1.5537924  -0.10975497  1.74548049
#   1.27313811  2.97876764  1.75207607  3.47317931  2.27168047 -0.89306007
#  -0.43568941  1.54952652  3.16798348 -0.28030395  3.49308092  2.18346586
#   1.78537358  1.0563182   1.1498758   1.61610603  2.00366419  0.77641005
#   0.96277792  1.30103802  3.33831544  2.13517835  3.54819416  0.47411099
#   1.76988805  1.10975881  0.25236054  1.67798358  1.54795703  0.63935163
#  -1.54871163  2.21907084  2.08841503  0.74649671  0.66329668  0.84680317
#   5.24998433 -0.94453481  3.19830047  1.27041114]
# summation:
# [ -5.07391051e-12  -6.47644709e-12  -5.38954491e-12  -1.26572240e-11
#   -7.62469659e-12  -1.71794375e-11]
#
#  w at 5 :
# [[ -9.83491331e-14  -8.75459628e-14  -1.34809079e-13  -1.52482876e-13
#    -1.42594079e-13  -1.23759644e-13]
#  [ -1.25534921e-13  -1.11451433e-13  -1.71837676e-13  -1.93302778e-13
#    -1.81832237e-13  -1.56700110e-13]
#  [ -1.04467170e-13  -9.31951152e-14  -1.43219615e-13  -1.62616867e-13
#    -1.51565333e-13  -1.32126665e-13]
#  [ -2.45338778e-13  -2.17429713e-13  -3.35220936e-13  -3.75515076e-13
#    -3.55125192e-13  -3.04181254e-13]
#  [ -1.47791787e-13  -1.31408436e-13  -2.02407731e-13  -2.28421222e-13
#    -2.14222760e-13  -1.85297889e-13]
#  [ -3.32994203e-13  -2.94484743e-13  -4.54648291e-13  -5.07117139e-13
#    -4.81626510e-13  -4.10359921e-13]]
# temp:
# [-0.30719658  1.66042612  0.69509836 -0.3880968  -1.67325209  1.67791436
#   0.75768698  2.2389657   0.18041967 -0.18868313  3.64667426  0.53581796
#   1.11587212  2.18770482  1.87663515  0.2053472   3.3404879  -2.28740895
#  -0.40570798  3.41283854 -1.1317233   1.72165014  1.5991773   1.86138882
#   2.63635249  1.03762781  2.14698754  1.57072319 -1.83617698  0.51534286
#  -0.6825148   0.20196074  2.95306536 -1.24143045  5.66689138 -0.83321432
#   0.93618698 -1.14900241  2.8801379   2.12242117  0.35103544  4.72990964
#  -0.51527028  0.25811345  3.1977269   2.56733203 -0.84196157  0.17827338
#  -0.3168056   1.12021275  1.49944073  1.62626147  0.19698492  2.24235093
#  -2.07346856  2.70085748  0.96041124  1.55278439 -0.11076298  1.74447249
#   1.2721301   2.97775964  1.75106807  3.47217131  2.27067246 -0.89406808
#  -0.43669742  1.54851852  3.16697547 -0.28131196  3.49207292  2.18245786
#   1.78436558  1.05531019  1.1488678   1.61509803  2.00265619  0.77540205
#   0.96176992  1.30003002  3.33730744  2.13417034  3.54718616  0.47310299
#   1.76888004  1.10875081  0.25135253  1.67697557  1.54694902  0.63834362
#  -1.54971964  2.21806283  2.08740703  0.7454887   0.66228867  0.84579516
#   5.24897632 -0.94554282  3.19729247  1.26940314]
# summation:
# [ -5.10511710e-15  -4.45019468e-15  -7.27003180e-15  -8.28494401e-15
#   -7.73949593e-15  -6.57393717e-15]
#
#  w at 6 :
# [[ -9.89539635e-17  -1.16800235e-16  -1.31630627e-16  -2.40328399e-16
#    -1.56302382e-16  -2.38013161e-16]
#  [ -8.62594125e-17  -1.01668254e-16  -1.14767019e-16  -2.08951583e-16
#    -1.36137014e-16  -2.06723120e-16]
#  [ -1.40917132e-16  -1.66200434e-16  -1.87400383e-16  -3.41605772e-16
#    -2.22455308e-16  -3.38172018e-16]
#  [ -1.60589469e-16  -1.88851635e-16  -2.13590317e-16  -3.87160919e-16
#    -2.53080272e-16  -3.82499228e-16]
#  [ -1.50016891e-16  -1.76964778e-16  -1.99559191e-16  -3.63934482e-16
#    -2.36882160e-16  -3.60276860e-16]
#  [ -1.27424528e-16  -1.49745573e-16  -1.69499643e-16  -3.06826967e-16
#    -2.00734808e-16  -3.02976709e-16]]
# temp:
# [-0.30820626  1.65941644  0.69408868 -0.38910648 -1.67426177  1.67690468
#   0.7566773   2.23795602  0.17940999 -0.18969281  3.64566458  0.53480828
#   1.11486244  2.18669514  1.87562547  0.20433752  3.33947822 -2.28841863
#  -0.40671766  3.41182886 -1.13273298  1.72064046  1.59816762  1.86037914
#   2.63534281  1.03661813  2.14597786  1.56971351 -1.83718666  0.51433318
#  -0.68352448  0.20095106  2.95205568 -1.24244013  5.66588171 -0.834224
#   0.9351773  -1.15001208  2.87912822  2.12141149  0.35002576  4.72889996
#  -0.51627996  0.25710377  3.19671722  2.56632235 -0.84297125  0.1772637
#  -0.31781528  1.11920307  1.49843105  1.62525179  0.19597524  2.24134125
#  -2.07447824  2.69984781  0.95940156  1.55177472 -0.11177265  1.74346281
#   1.27112042  2.97674996  1.75005839  3.47116163  2.26966278 -0.89507776
#  -0.4377071   1.54750884  3.1659658  -0.28232164  3.49106324  2.18144818
#   1.7833559   1.05430051  1.14785812  1.61408835  2.00164651  0.77439237
#   0.96076024  1.29902034  3.33629776  2.13316066  3.54617648  0.47209331
#   1.76787036  1.10774113  0.25034285  1.67596589  1.54593934  0.63733394
#  -1.55072932  2.21705315  2.08639735  0.74447902  0.66127899  0.84478548
#   5.24796664 -0.9465525   3.19628279  1.26839346]
# summation:
# [ -4.16344859e-18  -5.06403713e-18  -5.82384385e-18  -1.13222047e-17
#   -7.07265231e-18  -1.11963016e-17]
#
#  w at 7 :
# [[ -8.07012839e-20  -7.83940985e-20  -1.14107845e-19  -1.49429192e-19
#    -1.20346445e-19  -1.21834928e-19]
#  [ -9.81576424e-20  -9.52774072e-20  -1.38710378e-19  -1.81343714e-19
#    -1.46305398e-19  -1.47812396e-19]
#  [ -1.12885188e-19  -1.09660355e-19  -1.59586744e-19  -2.08973839e-19
#    -1.68335049e-19  -1.70391954e-19]
#  [ -2.19461447e-19  -2.12895868e-19  -3.09927110e-19  -4.04625518e-19
#    -3.26972195e-19  -3.29748369e-19]
#  [ -1.37091190e-19  -1.33107299e-19  -1.93757376e-19  -2.53463800e-19
#    -2.04374182e-19  -2.06622750e-19]
#  [ -2.17021034e-19  -2.10426601e-19  -3.06391192e-19  -3.99604257e-19
#    -3.23240381e-19  -3.25591510e-19]]
# temp:
# [-0.30921761  1.65840509  0.69307733 -0.39011783 -1.67527312  1.67589333
#   0.75566595  2.23694467  0.17839864 -0.19070416  3.64465323  0.53379693
#   1.11385109  2.18568379  1.87461412  0.20332617  3.33846687 -2.28942998
#  -0.40772901  3.41081751 -1.13374433  1.71962911  1.59715627  1.85936779
#   2.63433146  1.03560678  2.14496651  1.56870216 -1.83819801  0.51332183
#  -0.68453583  0.19993971  2.95104433 -1.24345148  5.66487035 -0.83523535
#   0.93416595 -1.15102344  2.87811687  2.12040014  0.34901441  4.72788861
#  -0.51729131  0.25609242  3.19570587  2.565311   -0.8439826   0.17625235
#  -0.31882663  1.11819172  1.4974197   1.62424044  0.19496389  2.2403299
#  -2.07548959  2.69883645  0.95839021  1.55076336 -0.11278401  1.74245146
#   1.27010907  2.97573861  1.74904704  3.47015028  2.26865143 -0.89608911
#  -0.43871845  1.54649749  3.16495444 -0.28333299  3.49005189  2.18043683
#   1.78234455  1.05328916  1.14684677  1.613077    2.00063516  0.77338102
#   0.95974889  1.29800899  3.33528641  2.13214931  3.54516513  0.47108196
#   1.76685901  1.10672978  0.2493315   1.67495454  1.54492799  0.63632259
#  -1.55174067  2.2160418   2.085386    0.74346767  0.66026764  0.84377413
#   5.24695529 -0.94756385  3.19527144  1.26738211]
# summation:
# [ -4.25067984e-21  -4.10599805e-21  -6.29989628e-21  -8.45709741e-21
#   -6.68402208e-21  -6.76292671e-21]
#
#  w at 8 :
# [[ -8.23920641e-23  -9.18094841e-23  -1.18569534e-22  -1.97767496e-22
#    -1.31564571e-22  -1.75267166e-22]
#  [ -7.95876584e-23  -8.86516017e-23  -1.14525753e-22  -1.90891569e-22
#    -1.27054729e-22  -1.69135754e-22]
#  [ -1.22112574e-22  -1.36030666e-22  -1.75706678e-22  -2.92904497e-22
#    -1.94946519e-22  -2.59542709e-22]
#  [ -1.63926181e-22  -1.82472581e-22  -2.35828371e-22  -3.92576700e-22
#    -2.61564230e-22  -3.47709433e-22]
#  [ -1.29558188e-22  -1.44329553e-22  -1.86432323e-22  -3.10809864e-22
#    -2.06843134e-22  -2.75408017e-22]
#  [ -1.31087617e-22  -1.45897799e-22  -1.88583779e-22  -3.13848212e-22
#    -2.09147330e-22  -2.77953232e-22]]
# temp:
# [-0.31023064  1.65739207  0.69206431 -0.39113085 -1.67628614  1.67488031
#   0.75465293  2.23593165  0.17738562 -0.19171718  3.64364021  0.53278391
#   1.11283806  2.18467077  1.8736011   0.20231315  3.33745385 -2.290443
#  -0.40874203  3.40980449 -1.13475735  1.71861609  1.59614325  1.85835477
#   2.63331844  1.03459376  2.14395349  1.56768913 -1.83921103  0.51230881
#  -0.68554885  0.19892669  2.95003131 -1.2444645   5.66385733 -0.83624837
#   0.93315293 -1.15203646  2.87710385  2.11938712  0.34800139  4.72687559
#  -0.51830433  0.25507939  3.19469285  2.56429798 -0.84499562  0.17523932
#  -0.31983966  1.1171787   1.49640668  1.62322741  0.19395087  2.23931688
#  -2.07650261  2.69782343  0.95737719  1.54975034 -0.11379703  1.74143843
#   1.26909605  2.97472559  1.74803402  3.46913726  2.26763841 -0.89710213
#  -0.43973147  1.54548446  3.16394142 -0.28434601  3.48903887  2.17942381
#   1.78133153  1.05227614  1.14583374  1.61206398  1.99962214  0.77236799
#   0.95873586  1.29699597  3.33427339  2.13113629  3.5441521   0.47006894
#   1.76584599  1.10571676  0.24831848  1.67394152  1.54391497  0.63530957
#  -1.55275369  2.21502878  2.08437298  0.74245465  0.65925462  0.84276111
#   5.24594227 -0.94857687  3.19425841  1.26636909]
# summation:
# [ -3.71700016e-24  -4.22587291e-24  -5.67787262e-24  -9.96449745e-24
#   -6.38137414e-24  -8.74358675e-24]
#
#  w at 9 :
# [[ -7.20475668e-26  -7.26980638e-26  -1.04376722e-25  -1.47011885e-25
#    -1.09895823e-25  -1.20595433e-25]
#  [ -8.19111777e-26  -8.26346337e-26  -1.18644453e-25  -1.67035566e-25
#    -1.24920638e-25  -1.37012836e-25]
#  [ -1.10055660e-25  -1.11043400e-25  -1.59425391e-25  -2.24515584e-25
#    -1.67860795e-25  -1.84171438e-25]
#  [ -1.93144408e-25  -1.94813297e-25  -2.79696224e-25  -3.93600109e-25
#    -2.94508314e-25  -3.22840247e-25]
#  [ -1.23691811e-25  -1.24791064e-25  -1.79168015e-25  -2.52273355e-25
#    -1.88647042e-25  -2.06934447e-25]
#  [ -1.69479183e-25  -1.70925627e-25  -2.45404932e-25  -3.45265696e-25
#    -2.58401657e-25  -2.83185032e-25]]
#
#  w final:
# [[ -7.20475668e-26  -7.26980638e-26  -1.04376722e-25  -1.47011885e-25
#    -1.09895823e-25  -1.20595433e-25]
#  [ -8.19111777e-26  -8.26346337e-26  -1.18644453e-25  -1.67035566e-25
#    -1.24920638e-25  -1.37012836e-25]
#  [ -1.10055660e-25  -1.11043400e-25  -1.59425391e-25  -2.24515584e-25
#    -1.67860795e-25  -1.84171438e-25]
#  [ -1.93144408e-25  -1.94813297e-25  -2.79696224e-25  -3.93600109e-25
#    -2.94508314e-25  -3.22840247e-25]
#  [ -1.23691811e-25  -1.24791064e-25  -1.79168015e-25  -2.52273355e-25
#    -1.88647042e-25  -2.06934447e-25]
#  [ -1.69479183e-25  -1.70925627e-25  -2.45404932e-25  -3.45265696e-25
#    -2.58401657e-25  -2.83185032e-25]]

# %% [markdown]
# ### 7. PCA Representation of MNIST (10 points)
#
# Download the MNIST dataset from here http://deeplearning.net/tutorial/gettingstarted.html (the page contains python code for loading the data). Run your algorithm on (part of) this dataset, and visualize the results.
