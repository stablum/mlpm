# %% [markdown]
# # Lab 2: Bayesian PCA
#
# ### Machine Learning: Principles and Methods, November 2013
#
# * The lab exercises should be made in groups of three people, or at least two people.
# * The deadline is Wednesday, 11 December, 23:59.
# * Assignment should be sent to T.S.Cohen at uva dot nl (Taco Cohen). The subject line of your email should be "[MLPM2013] lab#_lastname1\_lastname2\_lastname3".
# * Put your and your teammates' names in the body of the email
# * Attach the .IPYNB (IPython Notebook) file containing your code and answers. Naming of the file follows the same rule as the subject line. For example, if the subject line is "[MLPM2013] lab01\_Kingma\_Hu", the attached file should be "lab01\_Kingma\_Hu.ipynb". Only use underscores ("\_") to connect names, otherwise the files cannot be parsed.
#
# Notes on implementation:
#
# * You should write your code and answers in an IPython Notebook: http://ipython.org/notebook.html. If you have problems, please contact us.
# * Among the first lines of your notebook should be "%pylab inline". This imports all required modules, and your plots will appear inline.
# * NOTE: test your code and make sure we can run your notebook / scripts!

# %% [markdown]
# ### Introduction
#
# In this lab assignment, we will implement a variational algorithm for Bayesian PCA. Unlike regular PCA based on maximization of retained variance or minimization of projection error (see Bishop, 12.1.1 and 12.1.2), probabilistic PCA defines a proper density model over observed and latent variables. We will work with a fully Bayesian model this time, which is to say that we will put priors on our parameters and will be interested in learning the posterior over those parameters. Bayesian methods are very elegant, but require a shift in mindset: we are no longer looking for a point estimate of the parameters (as in maximum likelihood or MAP), but for a full posterior distribution.
#
# The integrals involved in a Bayesian analysis are usually analytically intractable, so that we must resort to approximations. In this lab assignment, we will implement the variational method described in Bishop99. Chapters 10 and 12 of the PRML book contain additional material that may be useful when doing this exercise.
#
# * [Bishop99] Variational Principal Components, C. Bishop, ICANN 1999 - http://research.microsoft.com/pubs/67241/bishop-vpca-icann-99.pdf
#
# Below, you will find some code to get you started.

# %%
# %pylab inline
import scipy.special as sp

class BayesianPCA(object):
    
    def __init__(self, d, N, a_alpha=10e-3, b_alpha=10e-3, a_tau=10e-3, b_tau=10e-3, beta=10e-3):
        
        self.d = d # number of dimensions
        self.N = N # number of data points
        
        # Hyperparameters
        self.a_alpha = a_alpha
        self.b_alpha = b_alpha
        self.a_tau = a_tau
        self.b_tau = b_tau
        self.beta = beta

        # Variational parameters
        self.means_x = np.random.randn(d, N)
        self.sigma_x = np.random.randn(d, d)
        self.mean_mu = np.random.randn(d, 1)
        self.sigma_mu = np.random.randn(d, d)
        self.means_w = np.random.randn(d, d)
        self.sigma_w = np.random.randn(d, d)
        self.a_alpha_tilde = self.a_alpha + d/2.0
        self.bs_alpha_tilde = np.abs(np.random.randn(d, 1))
        self.a_tau_tilde = self.a_tau + (N*d)/2.0
        self.b_tau_tilde = np.abs(np.random.randn(1)) 
    
    # WtW = E[W.t W]. element WtW(i,j) = sum_d E[W_id * W_dj] = sum_d cov(W_id, W_dj) + E[W_id] * E[W_dj] 
    # covariance is zero unless the two elements are in the same column, which is only  
    # the case during the summation if d = j so WtW(i,j) = sigma_w[i,j] + mean_w_i: * mean_w_:j
    def get_exp_WtW(self):
        return np.add( np.dot(self.means_w.T, self.means_w), self.sigma_w)
        
    
    def update_x(self, D):
        #update sigma of x
        exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
        exp_WtW = self.get_exp_WtW()
        to_invert = numpy.identity(self.d)+(exp_tau * exp_WtW)
        if np.linalg.det(to_invert)==0:
            print 'determinant is 0:\n', to_invert
        self.sigma_x = numpy.linalg.inv(to_invert)
                
        # update mu of x
        for n in range(self.N):
            diff = np.array([D[:,n]]).T - self.mean_mu 
            product1 = np.dot(self.sigma_x, self.means_w.T)
            product2 = np.dot(product1, diff)
            self.means_x[:,n] = exp_tau * product2[:,0]            
        
    
    def update_mu(self, D):
        # Update sigma of mu        
        exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
        self.sigma_mu = (1/float(self.beta+ self.N *exp_tau)) * numpy.identity(self.d)
                
        
        # Update means of mu 
        summed = np.zeros((self.d,1))
        for n in range(self.N):
            exp_xn = np.array([self.means_x[:,n]]).T
            tn = np.array([D[:,n]]).T
            product  = np.dot(self.means_w, exp_xn)
            diff = tn - product
            summed += diff
        final_product = np.dot(self.sigma_mu, summed)
        self.mean_mu = exp_tau *  final_product
        
            
    def update_w(self, D):
        # Update sigma of W
        exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
        
        exp_alpha = map( lambda x : self.a_alpha_tilde/float(x), self.bs_alpha_tilde)
        exp_alpha_diag = np.diag(exp_alpha)         
        
        sum_exp_xxt = np.zeros((self.d,self.d))
        for i in range(self.N):
            exp_x = np.array([self.means_x[:,i]]).T
            exp_xxt = np.dot(exp_x, exp_x.T) + self.sigma_x
            sum_exp_xxt = sum_exp_xxt +  exp_xxt
                
        self.sigma_w = numpy.linalg.inv(exp_alpha_diag +  (exp_tau * sum_exp_xxt))
                
        # Update mu of W
        # w(k) is a column
        for k in range(self.d):# for each column
            summed = np.zeros((self.d,1))
            for i in range(self.N):
                exp_xn = self.means_x[:,i]
                diff = D[k,i] - self.mean_mu[k]
                product = exp_xn * diff                
                summed = summed + array([product]).T
                        
            self.means_w[k,:] = np.dot(np.multiply(exp_tau, self.sigma_mu), summed)[:,0]        
        
        
    def update_alpha(self):
        # a_alpha_tilde is a constant: a_alpha + d/2 so set it in the initialization and do not change anymore
        
        # b alpha tilde
        for i in range(self.d):
            wi = np.array([self.means_w[:,i]]).T
            exp_wtw =  np.trace(self.sigma_w) + np.dot(wi.T, wi)
                        
            self.bs_alpha_tilde[i,0] = self.b_alpha + exp_wtw/2.0
                
        
    def update_tau(self, D):
        # a_tau is a constant so set in the initialization
        
        exp_WtW = self.get_exp_WtW()
        exp_mutmu = np.trace(self.sigma_mu) + np.dot(self.mean_mu.T, self.mean_mu)        
        summed = 0.0
        
        for i in range(self.N):
            tn = np.array([D[:,i]]).T
            exp_xn = np.array([self.means_x[:,i]]).T
            exp_xxt = np.dot(exp_xn, exp_xn.T) + self.sigma_x
            
            summed += np.dot(tn.T, tn) + exp_mutmu                         
            summed += np.trace(np.dot(exp_WtW, exp_xxt))
            summed += 2.0 * np.dot(np.dot(self.mean_mu.T, self.means_w), exp_xn)
            summed -= 2.0 * np.dot(np.dot(tn.T, self.means_w), exp_xn)
            summed -= 2.0 * np.dot(tn.T, self.mean_mu)
                
        self.b_tau_tilde = self.b_tau + 0.5* summed
        
        
        
    def L(self, X):
        L = 0.0
        return L
    
    def fit(self, X):
        print 'dimensions data:', X.shape
        print 'a alpha tilde =', self.a_alpha_tilde
        #self.update_tau(X)
  
        self.update_w(X)
        self.update_tau(X)
        self.update_mu(X)
        self.update_alpha()            
        self.update_x(X)  
                    
        #print '\n w at',i, ':\n', self.means_w
        
        #if i%5==0:                
            #print '\n w after',i+1, 'iterations:\n', self.means_w
            
            #print 'means of mu:', self.mean_mu.T
            #exp_tau = self.a_tau_tilde / float(self.b_tau_tilde)
            #print 'expectation of tau:', exp_tau
            #exp_alpha = map( lambda x : self.a_alpha_tilde/float(x), self.bs_alpha_tilde) 
            #print 'expectation of alpha:', exp_alpha
            #print 'bs of alpha:', self.bs_alpha_tilde.T
            #print '\n\n'
                
        #print '\n w final:\n', self.means_w
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_data(X):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X[0,:], X[1,:], zs=X[2,:])
    
    '''
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.scatter(X[0,:], X[1,:])
    
    fig3 = plt.figure()
    ax3 = fig3.add_subplot(111)
    ax3.scatter(X[0,:], X[2,:])
    
    fig4 = plt.figure()
    ax4 = fig4.add_subplot(111)
    ax4.scatter(X[2,:], X[1,:])              
    '''

# matrix with orthonormal vectors
A = np.array([ [0.4246,-0.1753,-0.1466,-0.0956,0.7864,0.3741]
                ,[0.5199,0.3483,0.2280,-0.4751,-0.4102,0.4031]
                ,[-0.2212,-0.7183,-0.2838,-0.2656,-0.3263,0.4213]
                ,[-0.5600,0.0724,0.6716,-0.1030,0.2397,0.4025]
                ,[0.2692,-0.1393,0.2114,0.8147,-0.2223,0.3876]
                ,[-0.3382,0.5544,-0.5918,0.1422,-0.0037,0.4558]])

a = np.array([[ 0.00339594,  0.0117771,  -0.01315114, -0.00609362,  0.00133929,  0.00365245],
 [ 0.00074487,  0.00258319, -0.00288457, -0.00133657,  0.00029376,  0.00080113],
 [ 0.00325301,  0.01128141, -0.01259761, -0.00583714,  0.00128292,  0.00349872],
 [-0.00357125, -0.01238505,  0.01383002,  0.00640818, -0.00140842, -0.003841  ],
 [ 0.0023858,  0.00827394, -0.00923927, -0.00428104,  0.00094091,  0.00256601],
 [-0.0053734,  -0.01863493,  0.02080907,  0.00964195, -0.00211916, -0.00577928]])


# eigenvalues on a diagonal matrix representing the magnitude of the variance
L = np.diag( [15,15,15,1,1,1])

# Covariance matrix generated based on A and L
covariance = np.dot(np.dot(a, L) , a.T)
means = [2,2,2,2,2,2]

dims = 6
N = 100

data = numpy.random.multivariate_normal(means, covariance, (N)).T



#print 'Plot of the first three dimensions of the data'
#plot_data(data)

bay_pca = BayesianPCA(dims,N)
bay_pca.fit(data, 50)
# Out:
# dimensions data: (6, 100)
# a alpha tilde = 3.01
# 0
# 10
# 20
# 30
# 40
#  w final:
# [[ -8.10861938e-16  -4.65167260e-14  -7.52665534e-15   7.51890220e-15
#     5.93161682e-14   5.19134334e-14]
#  [ -1.77854495e-16  -1.02029808e-14  -1.65089693e-15   1.64919636e-15
#     1.30104111e-14   1.13866949e-14]
#  [ -7.76733106e-16  -4.45588569e-14  -7.20986163e-15   7.20243483e-15
#     5.68195761e-14   4.97284192e-14]
#  [  8.52719826e-16   4.89179880e-14   7.91519237e-15  -7.90703902e-15
#    -6.23781562e-14  -5.45932813e-14]
#  [ -5.69666979e-16  -3.26800920e-14  -5.28781387e-15   5.28236695e-15
#     4.16722758e-14   3.64715217e-14]
#  [  1.28302831e-15   7.36034998e-14   1.19094404e-14  -1.18971726e-14
#    -9.38560803e-14  -8.21427196e-14]]

# %%
print bay_pca.means_w

hinton(bay_pca.means_w)
plt.title('w')
plt.show()
# Out:
# [[ -8.10861938e-16  -4.65167260e-14  -7.52665534e-15   7.51890220e-15
#     5.93161682e-14   5.19134334e-14]
#  [ -1.77854495e-16  -1.02029808e-14  -1.65089693e-15   1.64919636e-15
#     1.30104111e-14   1.13866949e-14]
#  [ -7.76733106e-16  -4.45588569e-14  -7.20986163e-15   7.20243483e-15
#     5.68195761e-14   4.97284192e-14]
#  [  8.52719826e-16   4.89179880e-14   7.91519237e-15  -7.90703902e-15
#    -6.23781562e-14  -5.45932813e-14]
#  [ -5.69666979e-16  -3.26800920e-14  -5.28781387e-15   5.28236695e-15
#     4.16722758e-14   3.64715217e-14]
#  [  1.28302831e-15   7.36034998e-14   1.19094404e-14  -1.18971726e-14
#    -9.38560803e-14  -8.21427196e-14]]

# %%
D = data

means_x = zeros((dims,10))

#print means_x
diff = np.array([D[:,0]]).T - bay_pca.mean_mu 
product1 = np.dot(bay_pca.sigma_x, bay_pca.means_w.T)
product2 = np.dot(product1, diff)

#print product2
#print product2[:,0]

means_x[:,0] =  product2[:,0]       

#print type(means_x)

# Update sigma of mu        
exp_tau = bay_pca.a_tau_tilde / float(bay_pca.b_tau_tilde)
sigma_mu = (1/float(bay_pca.beta+ bay_pca.N*exp_tau)) * numpy.identity(bay_pca.d)


# Update means of mu 
summed = np.zeros((bay_pca.d,1))

#print summed

for n in range(5):
    exp_xn = np.array([bay_pca.means_x[:,n]]).T
    tn = np.array([D[:,n]]).T
    product  = np.dot(bay_pca.means_w, exp_xn)
    diff = tn - product
    summed += diff
    
    #print summed
    
final_product = np.dot(bay_pca.sigma_mu, summed)
mean_mu = exp_tau *  final_product

#print mean_mu

# %%
# Code from https://gist.github.com/dwf/292018

def _blob(x, y, area, colour):
    """
    Draws a square-shaped blob with the given area (< 1) at
    the given coordinates.
    """
    hs = np.sqrt(area) / 2
    xcorners = np.array([x - hs, x + hs, x + hs, x - hs])
    ycorners = np.array([y - hs, y - hs, y + hs, y + hs])
    plt.fill(xcorners, ycorners, colour, edgecolor=colour)

def hinton(W, maxweight=None):
    """
    Draws a Hinton diagram for visualizing a weight matrix. 
    Temporarily disables matplotlib interactive mode if it is on, 
    otherwise this takes forever.
    """
    reenable = False
    if plt.isinteractive():
        plt.ioff()
    
    plt.clf()
    height, width = W.shape
    if not maxweight:
        maxweight = 2**np.ceil(np.log(np.max(np.abs(W)))/np.log(2))
        
    plt.fill(np.array([0, width, width, 0]), 
             np.array([0, 0, height, height]),
             'gray')
    
    plt.axis('off')
    plt.axis('equal')
    for x in xrange(width):
        for y in xrange(height):
            _x = x+1
            _y = y+1
            w = W[y, x]
            if w > 0:
                _blob(_x - 0.5,
                      height - _y + 0.5,
                      min(1, w/maxweight),
                      'white')
            elif w < 0:
                _blob(_x - 0.5,
                      height - _y + 0.5, 
                      min(1, -w/maxweight), 
                      'black')
    if reenable:
        plt.ion()

# %%
hinton(a)
plt.title('a')
plt.show()

    
hinton(A)
plt.title('A')
plt.show()

# %%
from IPython.display import display, Math, Latex


def learnBPCA(D, epsilon=0.01, maxIterations=sys.maxint) :
    
    [d,N] = shape(D)
    bPCA = BayesianPCA(d, N)
    
    prevL = -1 * sys.maxint 
    L = None
    Ldelta = sys.maxint
    
    iteration = 0
    while(Ldelta > epsilon and iteration < maxIterations):
        
        bPCA.fit(D)
        
        L = bPCA.L(D)
        
        #print "L:",L
        #Ldelta = L - prevL 
        #print "Ldelta",Ldelta
        
        prevL = L
        
        if (iteration % 10) == 0:
            print iteration
            
        if Ldelta < 0:
            raise Exception("Lower bound decreased")
            

learnBPCA(data, epsilon=1, maxIterations=1000)
# Out:
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[  6051.53048418   7193.74285143   5059.70444464 -23618.40900114
#    -3229.84785328  15303.390421  ]
#  [  4668.09895552   6376.25877952   4270.32689971 -19271.94523682
#    -2756.44904363  12110.05059506]
#  [ 11924.32677266  15691.99459958  10643.68410992 -48470.44468772
#    -6850.30397572  30714.47790283]
#  [  7963.92013913  13014.21804624   8233.99700317 -35597.94473325
#    -5386.94852555  21448.23936166]
#  [ 10569.58523998  14128.73737006   9531.9371116  -43243.12227767
#    -6142.36317756  27305.95459207]
#  [  1054.18120826   3884.6948949    2050.11412398  -7464.45268312
#    -1405.72214429   3636.76655394]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.18073424e-10  -1.36651036e-10  -9.70745852e-11   4.56105521e-10
#     6.18305363e-11  -2.97221303e-10]
#  [ -1.18813226e-10  -1.37405845e-10  -9.76377861e-11   4.58834220e-10
#     6.21854583e-11  -2.99046167e-10]
#  [ -1.16935459e-10  -1.35329843e-10  -9.61371456e-11   4.51704357e-10
#     6.12332882e-11  -2.94355209e-10]
#  [ -1.18918888e-10  -1.37364256e-10  -9.76518767e-11   4.59033758e-10
#     6.21882877e-11  -2.99251684e-10]
#  [ -1.17356136e-10  -1.35783347e-10  -9.64681902e-11   4.53286917e-10
#     6.14428921e-11  -2.95401853e-10]
#  [ -1.20603986e-10  -1.39244270e-10  -9.90061032e-11   4.65453729e-10
#     6.30482135e-11  -3.03467604e-10]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[  3.36612096e-20   4.28929418e-20   3.56078483e-20  -9.84508036e-20
#    -4.56420307e-20   6.17822612e-20]
#  [  3.38213292e-20   4.30969976e-20   3.57772384e-20  -9.89191350e-20
#    -4.58591514e-20   6.20761492e-20]
#  [  3.36698424e-20   4.29039435e-20   3.56169810e-20  -9.84760538e-20
#    -4.56537368e-20   6.17981062e-20]
#  [  3.40820140e-20   4.34292131e-20   3.60530161e-20  -9.96816073e-20
#    -4.62126372e-20   6.25546169e-20]
#  [  3.37222200e-20   4.29706932e-20   3.56723911e-20  -9.86292521e-20
#    -4.57247602e-20   6.18942414e-20]
#  [  3.41908607e-20   4.35679269e-20   3.61681647e-20  -9.99999714e-20
#    -4.63602323e-20   6.27543972e-20]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.61801809e-25  -3.17175941e-25  -2.49476626e-25   8.82858339e-25
#     3.05279075e-25  -5.66070288e-25]
#  [ -2.63047215e-25  -3.18684765e-25  -2.50663401e-25   8.87058146e-25
#     3.06731305e-25  -5.68763116e-25]
#  [ -2.61868956e-25  -3.17257289e-25  -2.49540612e-25   8.83084772e-25
#     3.05357373e-25  -5.66215472e-25]
#  [ -2.65074813e-25  -3.21141223e-25  -2.52595542e-25   8.93895690e-25
#     3.09095625e-25  -5.73147206e-25]
#  [ -2.62276347e-25  -3.17750848e-25  -2.49928823e-25   8.84458592e-25
#     3.05832419e-25  -5.67096337e-25]
#  [ -2.65921420e-25  -3.22166896e-25  -2.53402292e-25   8.96750650e-25
#     3.10082827e-25  -5.74977747e-25]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[  7.24227871e-28   8.84180534e-28   7.00172749e-28  -2.39741292e-27
#    -8.54349922e-28   1.53306456e-27]
#  [  7.27476454e-28   8.88146597e-28   7.03313430e-28  -2.40816671e-27
#    -8.58182177e-28   1.53994124e-27]
#  [  7.24403019e-28   8.84394365e-28   7.00342079e-28  -2.39799271e-27
#    -8.54556538e-28   1.53343532e-27]
#  [  7.32765346e-28   8.94603591e-28   7.08426652e-28  -2.42567454e-27
#    -8.64421325e-28   1.55113691e-27]
#  [  7.25465680e-28   8.85691724e-28   7.01369443e-28  -2.40151044e-27
#    -8.55810127e-28   1.53568478e-27]
#  [  7.34973679e-28   8.97299656e-28   7.10561636e-28  -2.43298479e-27
#    -8.67026429e-28   1.55581157e-27]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.83496067e-32  -2.24161957e-32  -1.77592590e-32   6.06547688e-32
#     2.16570078e-32  -3.87783227e-32]
#  [ -1.03775399e-32  -1.26773815e-32  -1.00436713e-32   3.43030395e-32
#     1.22480262e-32  -2.19309109e-32]
#  [ -1.79197898e-32  -2.18911239e-32  -1.73432702e-32   5.92340055e-32
#     2.11497191e-32  -3.78699882e-32]
#  [  2.60146596e-33   3.17799563e-33   2.51777100e-33  -8.59916611e-33
#    -3.07036383e-33   5.49769201e-33]
#  [ -1.53120084e-32  -1.87054133e-32  -1.48193870e-32   5.06139638e-32
#     1.80719016e-32  -3.23589498e-32]
#  [  8.02075139e-33   9.79828808e-33   7.76270595e-33  -2.65126566e-32
#    -9.46644136e-33   1.69502971e-32]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[  1.61618212e-34   1.97467743e-34   1.56461011e-34  -5.34032027e-34
#    -1.90762901e-34   3.41402848e-34]
#  [  3.54504351e-35   4.33139146e-35   3.43192197e-35  -1.17138208e-34
#    -4.18432291e-35   7.48856170e-35]
#  [  1.54815829e-34   1.89156482e-34   1.49875691e-34  -5.11555042e-34
#    -1.82733842e-34   3.27033472e-34]
#  [ -1.69958320e-34  -2.07657822e-34  -1.64534988e-34   5.61590090e-34
#     2.00606985e-34  -3.59020520e-34]
#  [  1.13544477e-34   1.38730477e-34   1.09921299e-34  -3.75182887e-34
#    -1.34020007e-34   2.39851731e-34]
#  [ -2.55725187e-34  -3.12449166e-34  -2.47565053e-34   8.44987940e-34
#     3.01840232e-34  -5.40194735e-34]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.26198504e-34  -1.54201661e-34  -1.22184784e-34   4.16932850e-34
#     1.48958726e-34  -2.66536137e-34]
#  [ -2.76803856e-35  -3.38225996e-35  -2.68000162e-35   9.14500706e-35
#     3.26726139e-35  -5.84620487e-35]
#  [ -1.20886863e-34  -1.47711379e-34  -1.17042079e-34   3.99384324e-34
#     1.42689117e-34  -2.55317745e-34]
#  [  1.32713056e-34   1.62161778e-34   1.28492143e-34  -4.38455538e-34
#    -1.56648195e-34   2.80295125e-34]
#  [ -8.86601244e-35  -1.08333602e-34  -8.58403060e-35   2.92914078e-34
#     1.04650204e-34  -1.87253623e-34]
#  [  1.99684121e-34   2.43993568e-34   1.93333205e-34  -6.59713603e-34
#    -2.35697662e-34   4.21740612e-34]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -8.84453743e-34  -1.08070564e-33  -8.56315660e-34   2.92208455e-33
#     1.04396542e-33  -1.86802908e-33]
#  [ -1.93996125e-34  -2.37042025e-34  -1.87824316e-34   6.40930161e-34
#     2.28983424e-34  -4.09733585e-34]
#  [ -8.47227463e-34  -1.03521920e-33  -8.20273700e-34   2.79909527e-33
#     1.00002537e-33  -1.78940454e-33]
#  [  9.30110548e-34   1.13649326e-33   9.00519936e-34  -3.07292686e-33
#    -1.09785646e-33   1.96445950e-33]
#  [ -6.21368531e-34  -7.59244314e-34  -6.01600262e-34   2.05289581e-33
#     7.33432661e-34  -1.31237444e-33]
#  [  1.39947276e-33   1.71000249e-33   1.35494982e-33  -4.62361968e-33
#    -1.65186838e-33   2.95578580e-33]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -5.13070539e-33  -6.26915995e-33  -4.96747633e-33   1.69509787e-32
#     6.05603063e-33  -1.08364153e-32]
#  [ -1.12536916e-33  -1.37507783e-33  -1.08956649e-33   3.71802846e-33
#     1.32833004e-33  -2.37685983e-33]
#  [ -4.91475620e-33  -6.00529369e-33  -4.75839738e-33   1.62375193e-32
#     5.80113489e-33  -1.03803152e-32]
#  [  5.39555997e-33   6.59278322e-33   5.22390478e-33  -1.78260132e-32
#    -6.36865185e-33   1.13958070e-32]
#  [ -3.60455128e-33  -4.40436681e-33  -3.48987553e-33   1.19088249e-32
#     4.25463388e-33  -7.61306909e-33]
#  [  8.11832443e-33   9.91970314e-33   7.86004680e-33  -2.68215643e-32
#    -9.58246823e-33   1.71464795e-32]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.96595143e-32  -3.62406774e-32  -2.87159219e-32   9.79899951e-32
#     3.50086222e-32  -6.26430071e-32]
#  [ -6.50551924e-33  -7.94903186e-33  -6.29855163e-33   2.14931301e-32
#     7.67879282e-33  -1.37401201e-32]
#  [ -2.84111580e-32  -3.47153228e-32  -2.75072810e-32   9.38656381e-32
#     3.35351243e-32  -6.00063898e-32]
#  [  3.11905821e-32   3.81114746e-32   3.01982801e-32  -1.03048383e-31
#    -3.68158189e-32   6.58767315e-32]
#  [ -2.08371427e-32  -2.54607057e-32  -2.01742266e-32   6.88423785e-32
#     2.45951316e-32  -4.40095298e-32]
#  [  4.69303032e-32   5.73436895e-32   4.54372551e-32  -1.55049747e-31
#    -5.53942064e-32   9.91201436e-32]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.71443379e-31  -2.09485029e-31  -1.65989053e-31   5.66419792e-31
#     2.02363277e-31  -3.62100631e-31]
#  [ -3.76043988e-32  -4.59484559e-32  -3.64080466e-32   1.24238543e-31
#     4.43863706e-32  -7.94231692e-32]
#  [ -1.64227401e-31  -2.00667894e-31  -1.59002645e-31   5.42579425e-31
#     1.93845893e-31  -3.46859970e-31]
#  [  1.80293539e-31   2.20298955e-31   1.74557652e-31  -5.95659216e-31
#    -2.12809568e-31   3.80792799e-31]
#  [ -1.20446684e-31  -1.47172654e-31  -1.16614775e-31   3.97935378e-31
#     1.42169303e-31  -2.54391978e-31]
#  [  2.71275170e-31   3.31468540e-31   2.62644779e-31  -8.96247062e-31
#    -3.20199780e-31   5.72952484e-31]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -9.91007180e-31  -1.21090221e-30  -9.59479122e-31   3.27411932e-30
#     1.16973581e-30  -2.09307776e-30]
#  [ -2.17367561e-31  -2.65599348e-31  -2.10452195e-31   7.18145483e-31
#     2.56569907e-31  -4.59095773e-31]
#  [ -9.49296112e-31  -1.15993586e-30  -9.19095056e-31   3.13631304e-30
#     1.12050213e-30  -2.00498102e-30]
#  [  1.04216443e-30   1.27341077e-30   1.00900885e-30  -3.44313418e-30
#    -1.23011930e-30   2.20112552e-30]
#  [ -6.96227113e-31  -8.50713263e-31  -6.74077234e-31   2.30021607e-30
#     8.21792014e-31  -1.47048126e-30]
#  [  1.56807245e-30   1.91601276e-30   1.51818555e-30  -5.18064492e-30
#    -1.85087509e-30   3.31188073e-30]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -5.72839387e-30  -6.99946978e-30  -5.54614985e-30   1.89256399e-29
#     6.76151251e-30  -1.20987759e-29]
#  [ -1.25646618e-30  -1.53526403e-30  -1.21649276e-30   4.15115073e-30
#     1.48307047e-30  -2.65374607e-30]
#  [ -5.48728822e-30  -6.70486510e-30  -5.31271477e-30   1.81290678e-29
#     6.47692334e-30  -1.15895436e-29]
#  [  6.02410200e-30   7.36079273e-30   5.83245027e-30  -1.99026093e-29
#    -7.11055175e-30   1.27233326e-29]
#  [ -4.02445432e-30  -4.91744231e-30  -3.89641970e-30   1.32961132e-29
#     4.75026663e-30  -8.49993422e-30]
#  [  9.06404798e-30   1.10752737e-29   8.77568294e-30  -2.99460743e-29
#    -1.06987535e-29   1.91439151e-29]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -3.31122689e-29  -4.04595654e-29  -3.20588300e-29   1.09397310e-28
#     3.90840829e-29  -6.99354709e-29]
#  [ -7.26284660e-30  -8.87440294e-30  -7.03178526e-30   2.39952110e-29
#     8.57270455e-30  -1.53396494e-29]
#  [ -3.17185877e-29  -3.87566396e-29  -3.07094876e-29   1.04792824e-28
#     3.74390506e-29  -6.69919169e-29]
#  [  3.48215731e-29   4.25481477e-29   3.37137541e-29  -1.15044560e-28
#    -4.11016608e-29   7.35456430e-29]
#  [ -2.32628581e-29  -2.84246643e-29  -2.25227699e-29   7.68565300e-29
#     2.74583260e-29  -4.91328136e-29]
#  [  5.23936031e-29   6.40192435e-29   5.07267448e-29  -1.73099561e-28
#    -6.18428151e-29   1.10659022e-28]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.91401356e-28  -2.33871490e-28  -1.85312083e-28   6.32357555e-28
#     2.25920685e-28  -4.04253300e-28]
#  [ -4.19819823e-29  -5.12973835e-29  -4.06463610e-29   1.38701335e-28
#     4.95534534e-29  -8.86689375e-29]
#  [ -1.83345355e-28  -2.24027939e-28  -1.77512377e-28   6.05741896e-28
#     2.16411780e-28  -3.87238451e-28]
#  [  2.01281776e-28   2.45944281e-28   1.94878166e-28  -6.65000784e-28
#    -2.37583043e-28   4.25121451e-28]
#  [ -1.34468061e-28  -1.64305240e-28  -1.30190073e-28   4.44259622e-28
#     1.58719441e-28  -2.84006124e-28]
#  [  3.02854712e-28   3.70055282e-28   2.93219645e-28  -1.00058050e-27
#    -3.57474708e-28   6.39650728e-28]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.10637176e-27  -1.35186509e-27  -1.07117347e-27   3.65526427e-27
#     1.30590645e-27  -2.33673597e-27]
#  [ -2.42671632e-28  -2.96518151e-28  -2.34951239e-28   8.01745835e-28
#     2.86437580e-28  -5.12539775e-28]
#  [ -1.05980504e-27  -1.29496567e-27  -1.02608824e-27   3.50141576e-27
#     1.25094140e-27  -2.23838375e-27]
#  [  1.16348430e-27   1.42165036e-27   1.12646902e-27  -3.84395440e-27
#    -1.37331926e-27   2.45736172e-27]
#  [ -7.77275916e-28  -9.49746022e-28  -7.52547538e-28   2.56798754e-27
#     9.17458009e-28  -1.64166211e-27]
#  [  1.75061403e-27   2.13905858e-27   1.69491972e-27  -5.78373128e-27
#    -2.06633813e-27   3.69742155e-27]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -6.39524446e-27  -7.81428816e-27  -6.19178515e-27   2.11288009e-26
#     7.54862994e-27  -1.35072119e-26]
#  [ -1.40273322e-27  -1.71398633e-27  -1.35810644e-27   4.63439218e-27
#     1.65571684e-27  -2.96267248e-27]
#  [ -6.12607136e-27  -7.48538812e-27  -5.93117557e-27   2.02394987e-26
#     7.23091133e-27  -1.29386991e-26]
#  [  6.72537640e-27   8.21767323e-27   6.51141423e-27  -2.22195008e-26
#    -7.93830134e-27   1.42044741e-26]
#  [ -4.49294685e-27  -5.48988887e-27  -4.35000754e-27   1.48439329e-26
#     5.30325202e-27  -9.48942382e-27]
#  [  1.01192069e-26   1.23645623e-26   9.79727286e-27  -3.34321400e-26
#    -1.19442108e-26   2.13724858e-26]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -3.69669160e-26  -4.51695217e-26  -3.57908447e-26   1.22132408e-25
#     4.36339174e-26  -7.80767600e-26]
#  [ -8.10832506e-27  -9.90748499e-27  -7.85036553e-27   2.67885281e-26
#     9.57066546e-27  -1.71253602e-26]
#  [ -3.54109943e-26  -4.32683559e-26  -3.42844234e-26   1.16991908e-25
#     4.17973845e-26  -7.47905426e-26]
#  [  3.88752026e-26   4.75012390e-26   3.76384208e-26  -1.28437063e-25
#    -4.58863645e-26   8.21071974e-26]
#  [ -2.59709210e-26  -3.17336205e-26  -2.51446780e-26   8.58035096e-26
#     3.06547893e-26  -5.48524353e-26]
#  [  5.84928180e-26   7.14718160e-26   5.66319184e-26  -1.93250331e-25
#    -6.90420265e-26   1.23540999e-25]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.13682664e-25  -2.61096808e-25  -2.06884530e-25   7.05971211e-25
#     2.52220438e-25  -4.51313010e-25]
#  [ -4.68691655e-26  -5.72689859e-26  -4.53780625e-26   1.54847758e-25
#     5.53220425e-26  -9.89910164e-26]
#  [ -2.04688852e-25  -2.50107355e-25  -1.98176849e-25   6.76257185e-25
#     2.41604587e-25  -4.32317438e-25]
#  [  2.24713278e-25   2.74575010e-25   2.17564215e-25  -7.42414485e-25
#    -2.65240428e-25   4.74610452e-25]
#  [ -1.50121682e-25  -1.83432250e-25  -1.45345687e-25   4.95976526e-25
#     1.77196201e-25  -3.17067686e-25]
#  [  3.38110466e-25   4.13133952e-25   3.27353767e-25  -1.11705953e-24
#    -3.99088855e-25   7.14113392e-25]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.23516609e-24  -1.50923765e-24  -1.19587032e-24   4.08077886e-24
#     1.45792890e-24  -2.60875877e-24]
#  [ -2.70921387e-25  -3.31036257e-25  -2.62302252e-25   8.95078225e-25
#     3.19782192e-25  -5.72205270e-25]
#  [ -1.18317848e-24  -1.44571449e-24  -1.14553665e-24   3.90902063e-24
#     1.39656530e-24  -2.49895723e-24]
#  [  1.29892718e-24   1.58714673e-24   1.25760291e-24  -4.29143468e-24
#    -1.53318934e-24   2.74342674e-24]
#  [ -8.67759727e-25  -1.06030733e-24  -8.40152683e-25   2.86693068e-24
#     1.02426062e-24  -1.83277036e-24]
#  [  1.95440554e-24   2.38806947e-24   1.89222777e-24  -6.45702378e-24
#    -2.30688354e-24   4.12784373e-24]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -7.13972410e-24  -8.72396073e-24  -6.91257980e-24   2.35884351e-23
#     8.42737684e-24  -1.50796059e-23]
#  [ -1.56602741e-24  -1.91351395e-24  -1.51620557e-24   5.17388846e-24
#     1.84846123e-24  -3.30756146e-24]
#  [ -6.83921617e-24  -8.35677295e-24  -6.62163227e-24   2.25956080e-23
#     8.07267216e-24  -1.44449118e-23]
#  [  7.50828718e-24   9.17430443e-24   7.26941735e-24  -2.48061049e-23
#    -8.86241045e-24   1.58580374e-23]
#  [ -5.01597728e-24  -6.12897476e-24  -4.85639819e-24   1.65719365e-23
#     5.92061124e-24  -1.05941013e-23]
#  [  1.12971984e-23   1.38039388e-23   1.09377875e-23  -3.73240236e-23
#    -1.33346536e-23   2.38604878e-23]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -4.12702880e-23  -5.04277710e-23  -3.99573086e-23   1.36350018e-22
#     4.87134047e-23  -8.71657883e-23]
#  [ -9.05222688e-24  -1.10608296e-23  -8.76423791e-24   2.99070193e-23
#     1.06848004e-23  -1.91189480e-23]
#  [ -3.95332392e-23  -4.83052877e-23  -3.82755226e-23   1.30611104e-22
#     4.66630783e-23  -8.34970176e-23]
#  [  4.34007211e-23   5.30309268e-23   4.20199637e-23  -1.43388607e-22
#    -5.12280624e-23   9.16654147e-23]
#  [ -2.89942334e-23  -3.54277770e-23  -2.80718063e-23   9.57920200e-23
#     3.42233576e-23  -6.12378864e-23]
#  [  6.53020514e-23   7.97919533e-23   6.32245217e-23  -2.15746881e-22
#    -7.70793084e-23   1.37922585e-22]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.38557772e-22  -2.91491464e-22  -2.30968257e-22   7.88154338e-22
#     2.81581783e-22  -5.03851008e-22]
#  [ -5.23252727e-23  -6.39357512e-23  -5.06605882e-23   1.72873809e-22
#     6.17621613e-23  -1.10514704e-22]
#  [ -2.28516977e-22  -2.79222713e-22  -2.21246902e-22   7.54981260e-22
#     2.69730126e-22  -4.82644135e-22]
#  [  2.50872475e-22   3.06538683e-22   2.42891179e-22  -8.28840027e-22
#    -2.96117449e-22   5.29860540e-22]
#  [ -1.67597563e-22  -2.04785863e-22  -1.62265588e-22   5.53713869e-22
#     1.97823866e-22  -3.53977993e-22]
#  [  3.77470394e-22   4.61227471e-22   3.65461492e-22  -1.24709804e-21
#    -4.45547365e-22   7.97244363e-22]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.37895356e-21  -1.68493019e-21  -1.33508331e-21   4.55582822e-21
#     1.62764851e-21  -2.91244815e-21]
#  [ -3.02459737e-22  -3.69572665e-22  -2.92837235e-22   9.99275572e-22
#     3.57008499e-22  -6.38816511e-22]
#  [ -1.32091399e-21  -1.61401220e-21  -1.27889023e-21   4.36407536e-21
#     1.55914148e-21  -2.78986445e-21]
#  [  1.45013717e-21   1.77190877e-21   1.40400228e-21  -4.79100678e-21
#    -1.71167012e-21   3.06279301e-21]
#  [ -9.68776889e-22  -1.18373923e-21  -9.37956069e-22   3.20067421e-21
#     1.14349628e-21  -2.04612581e-21]
#  [  2.18192071e-21   2.66606809e-21   2.11250474e-21  -7.20869524e-21
#    -2.57543118e-21   4.60837197e-21]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -7.97086968e-21  -9.73952958e-21  -7.71728319e-21   2.63343989e-20
#     9.40841994e-21  -1.68350446e-20]
#  [ -1.74833093e-21  -2.13626887e-21  -1.69270925e-21   5.77618828e-21
#     2.06364327e-21  -3.69259947e-21]
#  [ -7.63537919e-21  -9.32959695e-21  -7.39246604e-21   2.52259953e-20
#     9.01242357e-21  -1.61264648e-20]
#  [  8.38233772e-21   1.02422985e-20   8.11566072e-21  -2.76938194e-20
#    -9.89409644e-21   1.77040944e-20]
#  [ -5.59989443e-21  -6.84245755e-21  -5.42173851e-21   1.85010996e-20
#     6.60983814e-21  -1.18273760e-20]
#  [  1.26123215e-20   1.54108753e-20   1.22110712e-20  -4.16689671e-20
#    -1.48869599e-20   2.66381216e-20]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -4.60746218e-20  -5.62981405e-20  -4.46087965e-20   1.52222721e-19
#     5.43842024e-20  -9.73128835e-20]
#  [ -1.01060097e-20  -1.23484368e-20  -9.78449550e-21   3.33885386e-20
#     1.19286335e-20  -2.13446124e-20]
#  [ -4.41353607e-20  -5.39285759e-20  -4.27312314e-20   1.45815732e-19
#     5.20951946e-20  -9.32170259e-20]
#  [  4.84530616e-20   5.92043335e-20   4.69115683e-20  -1.60080682e-19
#    -5.71915951e-20   1.02336318e-19]
#  [ -3.23694939e-20  -3.95519756e-20  -3.13396858e-20   1.06943307e-19
#     3.82073480e-20  -6.83666772e-20]
#  [  7.29039574e-20   8.90806497e-20   7.05845795e-20  -2.40862287e-19
#    -8.60522219e-20   1.53978352e-19]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.66328626e-19  -3.25424406e-19  -2.57855605e-19   8.79904522e-19
#     3.14361124e-19  -5.62505031e-19]
#  [ -5.84165332e-20  -7.13786043e-20  -5.65580604e-20   1.92998299e-19
#     6.89519836e-20  -1.23379880e-19]
#  [ -2.55118968e-19  -3.11727432e-19  -2.47002573e-19   8.42869717e-19
#     3.01129799e-19  -5.38829435e-19]
#  [  2.80076902e-19   3.42223293e-19   2.71166492e-19  -9.25326490e-19
#    -3.30588909e-19   5.91542370e-19]
#  [ -1.87107837e-19  -2.28625281e-19  -1.81155159e-19   6.18172499e-19
#     2.20852828e-19  -3.95185082e-19]
#  [  4.21412267e-19   5.14919627e-19   4.08005391e-19  -1.39227452e-18
#    -4.97414176e-19   8.90052729e-19]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.53947953e-18  -1.88107534e-18  -1.49050229e-18   5.08617876e-18
#     1.81712542e-18  -3.25149044e-18]
#  [ -3.37669511e-19  -4.12595153e-19  -3.26926841e-19   1.11560268e-18
#     3.98568373e-19  -7.13182063e-19]
#  [ -1.47468349e-18  -1.80190169e-18  -1.42776768e-18   4.87210367e-18
#     1.74064339e-18  -3.11463660e-18]
#  [  1.61894973e-18   1.97817922e-18   1.56744421e-18  -5.34873480e-18
#    -1.91092811e-18   3.41933717e-18]
#  [ -1.08155360e-18  -1.32154003e-18  -1.04714489e-18   3.57326932e-18
#     1.27661233e-18  -2.28431826e-18]
#  [  2.43592125e-18   2.97642892e-18   2.35842447e-18  -8.04786985e-18
#    -2.87524084e-18   5.14483921e-18]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -8.89877013e-18  -1.08733223e-17  -8.61566326e-18   2.94000243e-17
#     1.05036677e-17  -1.87948365e-17]
#  [ -1.95185665e-18  -2.38495501e-18  -1.88975998e-18   6.44860269e-18
#     2.30387496e-18  -4.12246030e-18]
#  [ -8.52422470e-18  -1.04156688e-17  -8.25303368e-18   2.81625899e-17
#     1.00615728e-17  -1.80037698e-17]
#  [  9.35813775e-18   1.14346192e-17   9.06041649e-18  -3.09176969e-17
#    -1.10458825e-17   1.97650536e-17]
#  [ -6.25178622e-18  -7.63899791e-18  -6.05289092e-18   2.06548393e-17
#     7.37929893e-18  -1.32042179e-17]
#  [  1.40805401e-17   1.72048775e-17   1.36325796e-17  -4.65197117e-17
#    -1.66199724e-17   2.97391037e-17]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -5.14382350e-17  -6.28518883e-17  -4.98017709e-17   1.69943187e-16
#     6.07151459e-17  -1.08641217e-16]
#  [ -1.12824648e-17  -1.37859361e-17  -1.09235227e-17   3.72753466e-17
#     1.33172629e-17  -2.38293695e-17]
#  [ -4.92732217e-17  -6.02064792e-17  -4.77056357e-17   1.62790351e-16
#     5.81596714e-17  -1.04068554e-16]
#  [  5.40935525e-17   6.60963954e-17   5.23726117e-17  -1.78715905e-16
#    -6.38493512e-17   1.14249436e-16]
#  [ -3.61376734e-17  -4.41562782e-17  -3.49879838e-17   1.19392732e-16
#     4.26551206e-17  -7.63253407e-17]
#  [  8.13908123e-17   9.94506567e-17   7.88014323e-17  -2.68901413e-16
#    -9.60696853e-17   1.71903194e-16]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.97332326e-16  -3.63307531e-16  -2.87872948e-16   9.82335477e-16
#     3.50956356e-16  -6.27987054e-16]
#  [ -6.52168861e-17  -7.96878906e-17  -6.31420659e-17   2.15465509e-16
#     7.69787835e-17  -1.37742709e-16]
#  [ -2.84817735e-16  -3.48016072e-16  -2.75756499e-16   9.40989398e-16
#     3.36184754e-16  -6.01555347e-16]
#  [  3.12681058e-16   3.82062001e-16   3.02733374e-16  -1.03304508e-15
#    -3.69073241e-16   6.60404671e-16]
#  [ -2.08889331e-16  -2.55239879e-16  -2.02243693e-16   6.90134852e-16
#     2.46562624e-16  -4.41189148e-16]
#  [  4.70469477e-16   5.74862163e-16   4.55501888e-16  -1.55435120e-15
#    -5.55318878e-16   9.93665052e-16]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.71869256e-15  -2.10005404e-15  -1.66401381e-15   5.67826816e-15
#     2.02865961e-15  -3.63000113e-15]
#  [ -3.76978106e-16  -4.60625950e-16  -3.64984866e-16   1.24547160e-15
#     4.44966293e-16  -7.96204616e-16]
#  [ -1.64635353e-15  -2.01166366e-15  -1.59397618e-15   5.43927229e-15
#     1.94327419e-15  -3.47721594e-15]
#  [  1.80741401e-15   2.20846192e-15   1.74991265e-15  -5.97138873e-15
#    -2.13338201e-15   3.81738714e-15]
#  [ -1.20745882e-15  -1.47538241e-15  -1.16904454e-15   3.98923876e-15
#     1.42522461e-15  -2.55023905e-15]
#  [  2.71949035e-15   3.32291930e-15   2.63297206e-15  -8.98473400e-15
#    -3.20995177e-15   5.74375736e-15]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -9.93468880e-15  -1.21391014e-14  -9.61862505e-15   3.28225236e-14
#     1.17264148e-14  -2.09827705e-14]
#  [ -2.17907510e-15  -2.66259107e-15  -2.10974966e-15   7.19929384e-15
#     2.57207236e-15  -4.60236185e-15]
#  [ -9.51654200e-15  -1.16281718e-14  -9.21378124e-15   3.14410376e-14
#     1.12328550e-14  -2.00996147e-14]
#  [  1.04475321e-14   1.27657397e-14   1.01151527e-14  -3.45168706e-14
#    -1.23317496e-14   2.20659320e-14]
#  [ -6.97956568e-15  -8.52826468e-15  -6.75751668e-15   2.30592989e-14
#     8.23833377e-15  -1.47413399e-14]
#  [  1.57196761e-14   1.92077221e-14   1.52195678e-14  -5.19351384e-14
#    -1.85547274e-14   3.32010757e-14]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -5.74262341e-14  -7.01685673e-14  -5.55992669e-14   1.89726519e-13
#     6.77830836e-14  -1.21288298e-13]
#  [ -1.25958729e-14  -1.53907768e-14  -1.21951458e-14   4.16146235e-14
#     1.48675447e-14  -2.66033808e-14]
#  [ -5.50091885e-14  -6.72152024e-14  -5.32591176e-14   1.81741011e-13
#     6.49301227e-14  -1.16183325e-13]
#  [  6.03906610e-14   7.37907722e-14   5.84693830e-14  -1.99520481e-13
#    -7.12821463e-14   1.27549378e-13]
#  [ -4.03445121e-14  -4.92965743e-14  -3.90609855e-14   1.33291412e-13
#     4.76206647e-14  -8.52104838e-14]
#  [  9.08656342e-14   1.11027851e-13   8.79748207e-14  -3.00204614e-13
#    -1.07253296e-13   1.91914693e-13]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -3.31945211e-13  -4.05600685e-13  -3.21384654e-13   1.09669057e-12
#     3.91811692e-13  -7.01091933e-13]
#  [ -7.28088779e-14  -8.89644729e-14  -7.04925249e-14   2.40548160e-13
#     8.59399948e-14  -1.53777537e-13]
#  [ -3.17973779e-13  -3.88529125e-13  -3.07857711e-13   1.05053133e-12
#     3.75320506e-13  -6.71583274e-13]
#  [  3.49080712e-13   4.26538390e-13   3.37975003e-13  -1.15330335e-12
#    -4.12037589e-13   7.37283332e-13]
#  [ -2.33206439e-13  -2.84952722e-13  -2.25787173e-13   7.70474446e-13
#     2.75265335e-13  -4.92548613e-13]
#  [  5.25237508e-13   6.41782697e-13   5.08527520e-13  -1.73529547e-12
#    -6.19964350e-13   1.10933903e-12]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.91876804e-12  -2.34452436e-12  -1.85772406e-12   6.33928356e-12
#     2.26481880e-12  -4.05257480e-12]
#  [ -4.20862672e-13  -5.14248081e-13  -4.07473281e-13   1.39045875e-12
#     4.96765461e-13  -8.88891945e-13]
#  [ -1.83800792e-12  -2.24584433e-12  -1.77953325e-12   6.07246582e-12
#     2.16949355e-12  -3.88200366e-12]
#  [  2.01781768e-12   2.46555216e-12   1.95362251e-12  -6.66652671e-12
#    -2.38173209e-12   4.26177468e-12]
#  [ -1.34802084e-12  -1.64713380e-12  -1.30513470e-12   4.45363180e-12
#     1.59113707e-12  -2.84711606e-12]
#  [  3.03607015e-12   3.70974514e-12   2.93948014e-12  -1.00306598e-11
#    -3.58362689e-12   6.41239645e-12]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.10912003e-11  -1.35522317e-11  -1.07383431e-11   3.66434409e-11
#     1.30915037e-11  -2.34254051e-11]
#  [ -2.43274438e-12  -2.97254713e-12  -2.35534867e-12   8.03737402e-12
#     2.87149102e-12  -5.13812944e-12]
#  [ -1.06243764e-11  -1.29818241e-11  -1.02863708e-11   3.51011341e-11
#     1.25404879e-11  -2.24394398e-11]
#  [  1.16637444e-11   1.42518179e-11   1.12926722e-11  -3.85350293e-11
#    -1.37673064e-11   2.46346590e-11]
#  [ -7.79206699e-12  -9.52105228e-12  -7.54416895e-12   2.57436652e-11
#     9.19737009e-12  -1.64574006e-11]
#  [  1.75496262e-11   2.14437208e-11   1.69912997e-11  -5.79809829e-11
#    -2.07147100e-11   3.70660609e-11]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -6.41113049e-11  -7.83369915e-11  -6.20716578e-11   2.11812857e-10
#     7.56738102e-11  -1.35407643e-10]
#  [ -1.40621766e-11  -1.71824393e-11  -1.36148003e-11   4.64590418e-11
#     1.65982970e-11  -2.97003187e-11]
#  [ -6.14128875e-11  -7.50398211e-11  -5.94590883e-11   2.02897744e-10
#     7.24887319e-11  -1.29708394e-10]
#  [  6.74208249e-11   8.23808625e-11   6.52758883e-11  -2.22746949e-10
#    -7.95802038e-11   1.42397585e-10]
#  [ -4.50410750e-11  -5.50352596e-11  -4.36081312e-11   1.48808058e-10
#     5.31642550e-11  -9.51299591e-11]
#  [  1.01443434e-10   1.23952764e-10   9.82160966e-11  -3.35151867e-10
#    -1.19738807e-10   2.14255759e-10]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -3.70587432e-10  -4.52817246e-10  -3.58797505e-10   1.22435790e-09
#     4.37423057e-10  -7.82707057e-10]
#  [ -8.12846645e-11  -9.93209556e-11  -7.86986614e-11   2.68550718e-10
#     9.59443936e-11  -1.71679002e-10]
#  [ -3.54989565e-10  -4.33758361e-10  -3.43695872e-10   1.17282520e-09
#     4.19012108e-10  -7.49763252e-10]
#  [  3.89717701e-10   4.76192339e-10   3.77319161e-10  -1.28756106e-09
#    -4.60003480e-10   8.23111548e-10]
#  [ -2.60354337e-10  -3.18124480e-10  -2.52071384e-10   8.60166488e-10
#     3.07309370e-10  -5.49886908e-10]
#  [  5.86381164e-10   7.16493547e-10   5.67725942e-10  -1.93730372e-09
#    -6.92135295e-10   1.23847879e-09]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.14213460e-09  -2.61745382e-09  -2.07398440e-09   7.07724870e-09
#     2.52846963e-09  -4.52434088e-09]
#  [ -4.69855903e-10  -5.74112443e-10  -4.54907833e-10   1.55232406e-09
#     5.54594645e-10  -9.92369139e-10]
#  [ -2.05197307e-09  -2.50728631e-09  -1.98669128e-09   6.77937033e-09
#     2.42204742e-09  -4.33391331e-09]
#  [  2.25271475e-09   2.75257064e-09   2.18104653e-09  -7.44258671e-09
#    -2.65899296e-09   4.75789403e-09]
#  [ -1.50494590e-09  -1.83887903e-09  -1.45706731e-09   4.97208550e-09
#     1.77636363e-09  -3.17855295e-09]
#  [  3.38950346e-09   4.14160192e-09   3.28166926e-09  -1.11983434e-08
#    -4.00080207e-09   7.15887277e-09]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.23823429e-08  -1.51298666e-08  -1.19884091e-08   4.09091567e-08
#     1.46155045e-08  -2.61523903e-08]
#  [ -2.71594366e-09  -3.31858564e-09  -2.62953820e-09   8.97301633e-09
#     3.20576543e-09  -5.73626650e-09]
#  [ -1.18611754e-08  -1.44930570e-08  -1.14838221e-08   3.91873078e-08
#     1.40003442e-08  -2.50516474e-08]
#  [  1.30215377e-08   1.59108926e-08   1.26072684e-08  -4.30209477e-08
#    -1.53699784e-08   2.75024152e-08]
#  [ -8.69915275e-09  -1.06294117e-08  -8.42239654e-09   2.87405224e-08
#     1.02680492e-08  -1.83732303e-08]
#  [  1.95926036e-08   2.39400153e-08   1.89692814e-08  -6.47306327e-08
#    -2.31261392e-08   4.13809745e-08]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -7.15745944e-08  -8.74563138e-08  -6.92975091e-08   2.36470297e-07
#     8.44831077e-08  -1.51170642e-07]
#  [ -1.56991749e-08  -1.91826719e-08  -1.51997189e-08   5.18674059e-08
#     1.85305287e-08  -3.31577757e-08]
#  [ -6.85620504e-08  -8.37753149e-08  -6.63808066e-08   2.26517364e-07
#     8.09272498e-08  -1.44807935e-07]
#  [  7.52693805e-08   9.19709375e-08   7.28747486e-08  -2.48677242e-07
#    -8.88442502e-08   1.58974294e-07]
#  [ -5.02843715e-08  -6.14419936e-08  -4.86846167e-08   1.66131019e-07
#     5.93531826e-08  -1.06204175e-07]
#  [  1.13252610e-07   1.38382284e-07   1.09649574e-07  -3.74167379e-07
#    -1.33677774e-07   2.39197581e-07]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -4.13728049e-07  -5.05530354e-07  -4.00565640e-07   1.36688717e-06
#     4.88344106e-07  -8.73823114e-07]
#  [ -9.07471295e-08  -1.10883051e-07  -8.78600861e-08   2.99813095e-07
#     1.07113419e-07  -1.91664402e-07]
#  [ -3.96314413e-07  -4.84252798e-07  -3.83706004e-07   1.30935547e-06
#     4.67789912e-07  -8.37044274e-07]
#  [  4.35085301e-07   5.31626576e-07   4.21243429e-07  -1.43744790e-06
#    -5.13553148e-07   9.18931151e-07]
#  [ -2.90662561e-07  -3.55157809e-07  -2.81415377e-07   9.60299710e-07
#     3.43083697e-07  -6.13900037e-07]
#  [  6.54642642e-07   7.99901595e-07   6.33815738e-07  -2.16282804e-06
#    -7.72707763e-07   1.38265190e-06]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -2.39150357e-06  -2.92215539e-06  -2.31541990e-06   7.90112141e-06
#     2.82281241e-06  -5.05102591e-06]
#  [ -5.24552504e-07  -6.40945698e-07  -5.07864309e-07   1.73303234e-06
#     6.19155806e-07  -1.10789226e-06]
#  [ -2.29084621e-06  -2.79916312e-06  -2.21796487e-06   7.56856659e-06
#     2.70400145e-06  -4.83843040e-06]
#  [  2.51495651e-06   3.07300135e-06   2.43494529e-06  -8.30898894e-06
#    -2.96853015e-06   5.31176732e-06]
#  [ -1.68013881e-06  -2.05294558e-06  -1.62668661e-06   5.55089313e-06
#     1.98315267e-06  -3.54857287e-06]
#  [  3.78408043e-06   4.62373176e-06   3.66369310e-06  -1.25019587e-05
#    -4.46654119e-06   7.99224745e-06]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -1.38237875e-05  -1.68911540e-05  -1.33839954e-05   4.56714448e-05
#     1.63169144e-05  -2.91968240e-05]
#  [ -3.03211020e-06  -3.70490650e-06  -2.93564617e-06   1.00175768e-05
#     3.57895276e-06  -6.40403274e-06]
#  [ -1.32419502e-05  -1.61802126e-05  -1.28206687e-05   4.37491533e-05
#     1.56301424e-05  -2.79679422e-05]
#  [  1.45373918e-05   1.77631003e-05   1.40748969e-05  -4.80290721e-05
#    -1.71592175e-05   3.07040071e-05]
#  [ -9.71183244e-06  -1.18667954e-05  -9.40285868e-06   3.20862440e-05
#     1.14633662e-05  -2.05120820e-05]
#  [  2.18734040e-05   2.67269036e-05   2.11775201e-05  -7.22660099e-05
#    -2.58182832e-05   4.61981876e-05]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -7.99063547e-05  -9.76368121e-05  -7.73642014e-05   2.63997017e-04
#     9.43175050e-05  -1.68767914e-04]
#  [ -1.75266635e-05  -2.14156629e-05  -1.69690675e-05   5.79051180e-05
#     2.06876059e-05  -3.70175620e-05]
#  [ -7.65431304e-05  -9.35273205e-05  -7.41079753e-05   2.52885496e-04
#     9.03477216e-05  -1.61664544e-04]
#  [  8.40312385e-05   1.02676968e-04   8.13578555e-05  -2.77624932e-04
#    -9.91863136e-05   1.77479962e-04]
#  [ -5.61378079e-05  -6.85942516e-05  -5.43518308e-05   1.85469777e-04
#     6.62622890e-05  -1.18567049e-04]
#  [  1.26435970e-04   1.54490905e-04   1.22413516e-04  -4.17722958e-04
#    -1.49238759e-04   2.67041775e-04]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[ -4.61824772e-04  -5.64299280e-04  -4.47132206e-04   1.52579057e-03
#     5.45115096e-04  -9.75406818e-04]
#  [ -1.01296667e-04  -1.23773430e-04  -9.80739987e-05   3.34666973e-04
#     1.19565570e-04  -2.13945777e-04]
#  [ -4.42386765e-04  -5.40548165e-04  -4.28312603e-04   1.46157069e-03
#     5.22171435e-04  -9.34352362e-04]
#  [  4.85664847e-04   5.93429240e-04   4.70213829e-04  -1.60455412e-03
#    -5.73254740e-04   1.02575875e-03]
#  [ -3.24452672e-04  -3.96445623e-04  -3.14130484e-04   1.07193649e-03
#     3.82967870e-04  -6.85267157e-04]
#  [  7.30746172e-04   8.92891772e-04   7.07498099e-04  -2.41426117e-03
#    -8.62536603e-04   1.54338797e-03]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.00265722 -0.00324683 -0.00257268  0.00877901  0.00313645 -0.00561224]
#  [-0.00058284 -0.00071216 -0.00056429  0.00192559  0.00068795 -0.00123099]
#  [-0.00254538 -0.00311018 -0.0024644   0.0084095   0.00300444 -0.00537602]
#  [ 0.00279439  0.00341444  0.00270549 -0.00923219 -0.00329836  0.00590195]
#  [-0.00186682 -0.00228105 -0.00180743  0.00616765  0.0022035  -0.00394285]
#  [ 0.00420453  0.00513747  0.00407076 -0.01389104 -0.00496281  0.00888026]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01330969 -0.01626298 -0.01288625  0.04397295  0.0157101  -0.02811102]
#  [-0.00291935 -0.00356712 -0.00282647  0.00964503  0.00344585 -0.00616587]
#  [-0.01274949 -0.01557848 -0.01234388  0.04212215  0.01504887 -0.02692783]
#  [ 0.01399676  0.0171025   0.01355146 -0.0462429  -0.01652108  0.02956215]
#  [-0.00935066 -0.01142548 -0.00905317  0.03089298  0.01103705 -0.01974925]
#  [ 0.02105995  0.02573295  0.02038994 -0.06957849 -0.02485812  0.04448011]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01440117 -0.01759665 -0.01394301  0.04757891  0.01699843 -0.03041628]
#  [-0.00315875 -0.00385965 -0.00305826  0.01043596  0.00372844 -0.00667151]
#  [-0.01379503 -0.01685602 -0.01335616  0.04557634  0.01628297 -0.02913607]
#  [ 0.01514458  0.01850502  0.01466277 -0.05003501 -0.01787591  0.03198641]
#  [-0.01011747 -0.01236244 -0.00979559  0.03342633  0.01194216 -0.0213688 ]
#  [ 0.022787    0.02784321  0.02206205 -0.0752842  -0.02689664  0.04812773]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01494186 -0.01825714 -0.01446652  0.04935857  0.0176365  -0.03155635]
#  [-0.00327735 -0.00400452 -0.00317309  0.01082631  0.00386839 -0.00692157]
#  [-0.01431297 -0.0174887  -0.01385763  0.04728109  0.01689418 -0.03022816]
#  [ 0.01571319  0.0191996   0.0152133  -0.05190653 -0.01854692  0.03318534]
#  [-0.01049733 -0.01282646 -0.01016338  0.03467662  0.01239043 -0.02216976]
#  [ 0.02364254  0.02888831  0.0228904  -0.07810016 -0.02790626  0.04993167]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01471119 -0.01797524 -0.01424319  0.04859497  0.01736419 -0.03106871]
#  [-0.00322675 -0.00394269 -0.0031241   0.01065882  0.00380866 -0.00681461]
#  [-0.014092   -0.01721867 -0.0136437   0.04654963  0.01663334 -0.02976105]
#  [ 0.0154706   0.01890315  0.01497844 -0.05110351 -0.01826055  0.03267253]
#  [-0.01033527 -0.01262841 -0.01000648  0.03414015  0.01219912 -0.02182717]
#  [ 0.02327754  0.02844225  0.02253702 -0.07689191 -0.02747538  0.04916008]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499824 -0.01832597 -0.01452111  0.04954289  0.01770299 -0.03167485]
#  [-0.00328971 -0.00401962 -0.00318506  0.01086674  0.00388298 -0.00694756]
#  [-0.01436697 -0.01755464 -0.01390992  0.04745765  0.01695788 -0.03034167]
#  [ 0.01577247  0.01927198  0.01527071 -0.05210037 -0.01861685  0.03330996]
#  [-0.01053694 -0.01287482 -0.01020173  0.03480611  0.01243715 -0.02225301]
#  [ 0.02373174  0.02899721  0.02297677 -0.07839181 -0.02801148  0.05011918]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01472284 -0.01798947 -0.01425447  0.04863315  0.01737793 -0.03109323]
#  [-0.00322931 -0.00394581 -0.00312658  0.0106672   0.00381168 -0.00681999]
#  [-0.01410316 -0.0172323  -0.01365451  0.0465862   0.0166465  -0.02978453]
#  [ 0.01548286  0.01891811  0.01499031 -0.05114366 -0.01827501  0.03269831]
#  [-0.01034346 -0.01263841 -0.01001441  0.03416697  0.01220878 -0.02184439]
#  [ 0.02329598  0.02846477  0.02255488 -0.07695231 -0.02749714  0.04919887]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499936 -0.01832734 -0.0145222   0.04954653  0.01770432 -0.03167721]
#  [-0.00328996 -0.00401992 -0.0031853   0.01086754  0.00388327 -0.00694808]
#  [-0.01436805 -0.01755595 -0.01391096  0.04746114  0.01695915 -0.03034393]
#  [ 0.01577365  0.01927343  0.01527185 -0.0521042  -0.01861825  0.03331243]
#  [-0.01053773 -0.01287578 -0.0102025   0.03480867  0.01243808 -0.02225466]
#  [ 0.02373352  0.02899939  0.0229785  -0.07839757 -0.02801358  0.0501229 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01472409 -0.01799099 -0.01425568  0.04863722  0.01737941 -0.03109585]
#  [-0.00322958 -0.00394615 -0.00312684  0.01066809  0.003812   -0.00682057]
#  [-0.01410436 -0.01723376 -0.01365567  0.0465901   0.01664792 -0.02978704]
#  [ 0.01548417  0.01891972  0.01499158 -0.05114795 -0.01827656  0.03270107]
#  [-0.01034434 -0.01263948 -0.01001526  0.03416984  0.01220982 -0.02184624]
#  [ 0.02329796  0.02846718  0.02255679 -0.07695877 -0.02749947  0.04920303]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499858 -0.01832638 -0.01452143  0.04954389  0.01770339 -0.03167553]
#  [-0.00328979 -0.00401971 -0.00318513  0.01086696  0.00388306 -0.00694771]
#  [-0.01436729 -0.01755503 -0.01391023  0.0474586   0.01695826 -0.03034232]
#  [ 0.01577283  0.01927241  0.01527105 -0.05210141 -0.01861727  0.03331067]
#  [-0.01053717 -0.0128751  -0.01020196  0.03480681  0.01243743 -0.02225348]
#  [ 0.02373227  0.02899786  0.02297729 -0.07839338 -0.02801211  0.05012025]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01472498 -0.01799207 -0.01425654  0.04864009  0.01738045 -0.0310977 ]
#  [-0.00322978 -0.00394638 -0.00312703  0.01066872  0.00381223 -0.00682097]
#  [-0.01410521 -0.01723479 -0.01365649  0.04659285  0.01664891 -0.02978882]
#  [ 0.0154851   0.01892085  0.01499248 -0.05115097 -0.01827765  0.03270301]
#  [-0.01034496 -0.01264024 -0.01001586  0.03417185  0.01221055 -0.02184754]
#  [ 0.02329935  0.02846889  0.02255814 -0.07696331 -0.02750112  0.04920595]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499773 -0.01832534 -0.01452061  0.04954104  0.01770239 -0.03167372]
#  [-0.0032896  -0.00401948 -0.00318495  0.01086633  0.00388284 -0.00694732]
#  [-0.01436648 -0.01755403 -0.01390945  0.04745587  0.0169573  -0.03034059]
#  [ 0.01577193  0.01927132  0.01527019 -0.05209842 -0.01861621  0.03330877]
#  [-0.01053658 -0.01287438 -0.01020138  0.03480481  0.01243672 -0.02225222]
#  [ 0.02373093  0.02899622  0.02297599 -0.07838887 -0.02801052  0.05011739]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01472584 -0.01799313 -0.01425737  0.0486429   0.01738147 -0.03109952]
#  [-0.00322997 -0.00394661 -0.00312721  0.01066934  0.00381245 -0.00682137]
#  [-0.01410604 -0.0172358  -0.01365729  0.04659554  0.01664989 -0.02979055]
#  [ 0.01548601  0.01892196  0.01499336 -0.05115392 -0.01827873  0.03270492]
#  [-0.01034556 -0.01264098 -0.01001645  0.03417383  0.01221126 -0.02184881]
#  [ 0.02330072  0.02847056  0.02255947 -0.07696775 -0.02750273  0.04920882]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499688 -0.01832431 -0.01451979  0.0495382   0.01770139 -0.03167193]
#  [-0.00328942 -0.00401925 -0.00318477  0.01086571  0.00388262 -0.00694692]
#  [-0.01436567 -0.01755304 -0.01390866  0.04745315  0.01695635 -0.03033887]
#  [ 0.01577104  0.01927023  0.01526933 -0.05209543 -0.01861516  0.03330688]
#  [-0.01053598 -0.01287365 -0.01020081  0.03480281  0.01243602 -0.02225095]
#  [ 0.02372959  0.02899458  0.0229747  -0.07838438 -0.02800894  0.05011454]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.0147267  -0.01799417 -0.01425821  0.04864569  0.01738248 -0.03110132]
#  [-0.00323015 -0.00394684 -0.0031274   0.01066995  0.00381267 -0.00682176]
#  [-0.01410686 -0.01723681 -0.01365808  0.04659822  0.01665086 -0.02979228]
#  [ 0.01548691  0.01892306  0.01499423 -0.05115685 -0.01827979  0.03270681]
#  [-0.01034617 -0.01264172 -0.01001703  0.03417579  0.01221197 -0.02185007]
#  [ 0.02330208  0.02847221  0.02256078 -0.07697217 -0.02750433  0.04921167]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499604 -0.01832328 -0.01451898  0.04953537  0.0177004  -0.03167014]
#  [-0.00328923 -0.00401903 -0.00318459  0.01086509  0.00388241 -0.00694653]
#  [-0.01436487 -0.01755206 -0.01390788  0.04745045  0.0169554  -0.03033715]
#  [ 0.01577016  0.01926915  0.01526847 -0.05209246 -0.01861412  0.033305  ]
#  [-0.01053539 -0.01287293 -0.01020024  0.03480083  0.01243533 -0.0222497 ]
#  [ 0.02372826  0.02899295  0.02297341 -0.07837991 -0.02800737  0.05011172]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01472755 -0.01799521 -0.01425903  0.04864846  0.01738349 -0.0311031 ]
#  [-0.00323034 -0.00394707 -0.00312758  0.01067056  0.00381289 -0.00682216]
#  [-0.01410767 -0.0172378  -0.01365887  0.04660087  0.01665182 -0.02979399]
#  [ 0.01548781  0.01892415  0.0149951  -0.05115977 -0.01828085  0.03270869]
#  [-0.01034677 -0.01264245 -0.01001761  0.03417773  0.01221268 -0.02185133]
#  [ 0.02330343  0.02847386  0.02256209 -0.07697655 -0.02750592  0.0492145 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499521 -0.01832226 -0.01451817  0.04953257  0.01769941 -0.03166836]
#  [-0.00328905 -0.0040188  -0.00318442  0.01086448  0.00388219 -0.00694614]
#  [-0.01436407 -0.01755108 -0.01390711  0.04744777  0.01695445 -0.03033545]
#  [ 0.01576928  0.01926808  0.01526762 -0.05208952 -0.01861308  0.03330313]
#  [-0.01053481 -0.01287221 -0.01019967  0.03479886  0.01243463 -0.02224845]
#  [ 0.02372694  0.02899134  0.02297213 -0.07837548 -0.02800581  0.0501089 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.0147284  -0.01799625 -0.01425985  0.04865122  0.01738449 -0.03110488]
#  [-0.00323053 -0.0039473  -0.00312776  0.01067116  0.00381311 -0.00682255]
#  [-0.01410849 -0.01723879 -0.01365966  0.04660351  0.01665278 -0.02979569]
#  [ 0.0154887   0.01892524  0.01499597 -0.05116267 -0.0182819   0.03271056]
#  [-0.01034736 -0.01264317 -0.01001819  0.03417967  0.01221338 -0.02185258]
#  [ 0.02330477  0.0284755   0.02256339 -0.07698091 -0.0275075   0.04921731]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499438 -0.01832124 -0.01451737  0.04952979  0.01769843 -0.0316666 ]
#  [-0.00328887 -0.00401858 -0.00318424  0.01086387  0.00388197 -0.00694575]
#  [-0.01436327 -0.01755011 -0.01390634  0.0474451   0.01695351 -0.03033376]
#  [ 0.01576841  0.01926701  0.01526678 -0.05208659 -0.01861205  0.03330127]
#  [-0.01053423 -0.0128715  -0.01019911  0.0347969   0.01243394 -0.02224721]
#  [ 0.02372563  0.02898973  0.02297086 -0.07837107 -0.02800426  0.05010611]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01472924 -0.01799728 -0.01426067  0.04865395  0.01738548 -0.03110665]
#  [-0.00323071 -0.00394752 -0.00312794  0.01067176  0.00381333 -0.00682293]
#  [-0.01410929 -0.01723978 -0.01366044  0.04660613  0.01665373 -0.02979738]
#  [ 0.01548959  0.01892632  0.01499682 -0.05116554 -0.01828294  0.03271242]
#  [-0.01034795 -0.0126439  -0.01001876  0.03418159  0.01221408 -0.02185382]
#  [ 0.0233061   0.02847712  0.02256468 -0.07698524 -0.02750907  0.0492201 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499355 -0.01832023 -0.01451657  0.04952702  0.01769746 -0.03166484]
#  [-0.00328869 -0.00401836 -0.00318407  0.01086326  0.00388176 -0.00694537]
#  [-0.01436248 -0.01754914 -0.01390558  0.04744245  0.01695258 -0.03033208]
#  [ 0.01576754  0.01926595  0.01526594 -0.05208368 -0.01861103  0.03329943]
#  [-0.01053365 -0.01287079 -0.01019855  0.03479496  0.01243326 -0.02224598]
#  [ 0.02372433  0.02898814  0.0229696  -0.07836669 -0.02800272  0.05010334]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01473008 -0.0179983  -0.01426148  0.04865667  0.01738647 -0.0311084 ]
#  [-0.0032309  -0.00394775 -0.00312811  0.01067236  0.00381355 -0.00682332]
#  [-0.01411009 -0.01724076 -0.01366122  0.04660873  0.01665468 -0.02979906]
#  [ 0.01549047  0.0189274   0.01499768 -0.0511684  -0.01828398  0.03271426]
#  [-0.01034854 -0.01264461 -0.01001933  0.0341835   0.01221477 -0.02185505]
#  [ 0.02330743  0.02847874  0.02256596 -0.07698954 -0.02751064  0.04922288]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499274 -0.01831923 -0.01451578  0.04952427  0.01769649 -0.0316631 ]
#  [-0.00328851 -0.00401814 -0.00318389  0.01086266  0.00388155 -0.00694499]
#  [-0.0143617  -0.01754818 -0.01390482  0.04743981  0.01695165 -0.03033041]
#  [ 0.01576668  0.0192649   0.01526511 -0.05208079 -0.01861001  0.0332976 ]
#  [-0.01053307 -0.01287008 -0.01019799  0.03479303  0.01243258 -0.02224475]
#  [ 0.02372303  0.02898655  0.02296835 -0.07836234 -0.02800119  0.05010058]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01473091 -0.01799931 -0.01426228  0.04865937  0.01738745 -0.03111014]
#  [-0.00323108 -0.00394797 -0.00312829  0.01067295  0.00381376 -0.0068237 ]
#  [-0.01411089 -0.01724173 -0.01366199  0.04661132  0.01665562 -0.02980073]
#  [ 0.01549134  0.01892846  0.01499852 -0.05117124 -0.01828501  0.03271609]
#  [-0.01034913 -0.01264533 -0.0100199   0.0341854   0.01221546 -0.02185627]
#  [ 0.02330874  0.02848034  0.02256724 -0.07699382 -0.02751219  0.04922563]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499192 -0.01831824 -0.01451499  0.04952154  0.01769553 -0.03166137]
#  [-0.00328833 -0.00401792 -0.00318372  0.01086206  0.00388134 -0.00694461]
#  [-0.01436092 -0.01754723 -0.01390406  0.0474372   0.01695073 -0.03032876]
#  [ 0.01576583  0.01926385  0.01526428 -0.05207791 -0.018609    0.03329578]
#  [-0.0105325  -0.01286939 -0.01019744  0.03479111  0.01243191 -0.02224354]
#  [ 0.02372175  0.02898498  0.0229671  -0.07835802 -0.02799967  0.05009784]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01473174 -0.01800032 -0.01426308  0.04866206  0.01738842 -0.03111187]
#  [-0.00323126 -0.00394819 -0.00312847  0.01067354  0.00381398 -0.00682408]
#  [-0.01411168 -0.01724269 -0.01366276  0.04661389  0.01665655 -0.02980239]
#  [ 0.01549221  0.01892952  0.01499936 -0.05117406 -0.01828604  0.03271791]
#  [-0.01034971 -0.01264603 -0.01002046  0.03418728  0.01221615 -0.02185749]
#  [ 0.02331005  0.02848194  0.0225685  -0.07699806 -0.02751373  0.04922837]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01499112 -0.01831725 -0.01451421  0.04951882  0.01769458 -0.03165965]
#  [-0.00328815 -0.00401771 -0.00318355  0.01086146  0.00388113 -0.00694423]
#  [-0.01436015 -0.01754628 -0.01390331  0.0474346   0.01694982 -0.03032711]
#  [ 0.01576498  0.01926281  0.01526346 -0.05207506 -0.018608    0.03329397]
#  [-0.01053193 -0.01286869 -0.01019689  0.0347892   0.01243124 -0.02224233]
# ...
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01483935 -0.01813147 -0.01436731  0.04900562  0.01751517 -0.0313356 ]
#  [-0.00325486 -0.00397696 -0.00315133  0.0107489   0.00384178 -0.00687315]
#  [-0.01421477 -0.01736832 -0.0137626   0.046943    0.01677797 -0.0300167 ]
#  [ 0.01560538  0.01906744  0.01510897 -0.05153536 -0.01841933  0.03295319]
#  [-0.01042531 -0.01273817 -0.01009368  0.03442865  0.0123052  -0.02201467]
#  [ 0.02348033  0.02868945  0.02273342 -0.07754168 -0.02771429  0.04958237]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488837 -0.01819136 -0.01441477  0.04916747  0.01757303 -0.0314391 ]
#  [-0.00326561 -0.00399009 -0.00316174  0.0107844   0.00385447 -0.00689585]
#  [-0.01426172 -0.01742569 -0.01380806  0.04709804  0.01683339 -0.03011584]
#  [ 0.01565693  0.01913042  0.01515888 -0.05170557 -0.01848017  0.03306203]
#  [-0.01045975 -0.01278025 -0.01012702  0.03454236  0.01234584 -0.02208738]
#  [ 0.02355789  0.02878422  0.02280851 -0.07779778 -0.02780584  0.04974614]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01483951 -0.01813166 -0.01436746  0.04900611  0.01751536 -0.03133592]
#  [-0.0032549  -0.003977   -0.00315136  0.010749    0.00384182 -0.00687322]
#  [-0.01421492 -0.01736851 -0.01376274  0.04694346  0.01677815 -0.03001701]
#  [ 0.01560555  0.01906764  0.01510913 -0.05153587 -0.01841953  0.03295353]
#  [-0.01042542 -0.01273831 -0.01009379  0.03442899  0.01230533 -0.0220149 ]
#  [ 0.02348058  0.02868976  0.02273366 -0.07754245 -0.02771459  0.04958289]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488822 -0.01819118 -0.01441463  0.04916696  0.01757286 -0.03143879]
#  [-0.00326558 -0.00399005 -0.00316171  0.01078428  0.00385443 -0.00689578]
#  [-0.01426158 -0.01742552 -0.01380792  0.04709754  0.01683323 -0.03011554]
#  [ 0.01565678  0.01913024  0.01515873 -0.05170503 -0.01848     0.0330617 ]
#  [-0.01045965 -0.01278012 -0.01012693  0.034542    0.01234572 -0.02208716]
#  [ 0.02355766  0.02878394  0.02280829 -0.07779697 -0.02780557  0.04974565]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01483967 -0.01813185 -0.01436762  0.04900659  0.01751555 -0.03133625]
#  [-0.00325493 -0.00397704 -0.00315139  0.01074911  0.00384186 -0.00687329]
#  [-0.01421507 -0.01736869 -0.01376289  0.04694392  0.01677833 -0.03001732]
#  [ 0.01560571  0.01906785  0.0151093  -0.05153638 -0.01841973  0.03295387]
#  [-0.01042553 -0.01273844 -0.0100939   0.03442933  0.01230546 -0.02201512]
#  [ 0.02348083  0.02869006  0.02273391 -0.07754321 -0.02771488  0.0495834 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488808 -0.01819101 -0.01441449  0.04916645  0.01757269 -0.03143847]
#  [-0.00326555 -0.00399002 -0.00316168  0.01078417  0.00385439 -0.00689572]
#  [-0.01426145 -0.01742536 -0.01380779  0.04709705  0.01683306 -0.03011524]
#  [ 0.01565663  0.01913005  0.01515859 -0.05170449 -0.01847982  0.03306137]
#  [-0.01045955 -0.01278    -0.01012683  0.03454164  0.01234561 -0.02208694]
#  [ 0.02355744  0.02878366  0.02280808 -0.07779616 -0.0278053   0.04974515]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01483983 -0.01813205 -0.01436777  0.04900707  0.01751573 -0.03133657]
#  [-0.00325497 -0.00397708 -0.00315143  0.01074921  0.0038419  -0.00687336]
#  [-0.01421522 -0.01736888 -0.01376304  0.04694438  0.0167785  -0.03001763]
#  [ 0.01560588  0.01906805  0.01510946 -0.05153688 -0.01841992  0.03295421]
#  [-0.01042565 -0.01273858 -0.01009401  0.03442967  0.01230559 -0.02201535]
#  [ 0.02348108  0.02869037  0.02273415 -0.07754397 -0.02771518  0.04958391]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488794 -0.01819083 -0.01441436  0.04916594  0.01757252 -0.03143816]
#  [-0.00326552 -0.00398998 -0.00316165  0.01078406  0.00385436 -0.00689565]
#  [-0.01426131 -0.01742519 -0.01380766  0.04709657  0.0168329  -0.03011495]
#  [ 0.01565648  0.01912987  0.01515845 -0.05170396 -0.01847964  0.03306105]
#  [-0.01045945 -0.01277988 -0.01012673  0.03454128  0.01234549 -0.02208672]
#  [ 0.02355722  0.02878339  0.02280786 -0.07779536 -0.02780504  0.04974466]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01483998 -0.01813224 -0.01436792  0.04900754  0.01751592 -0.03133689]
#  [-0.003255   -0.00397713 -0.00315146  0.01074932  0.00384194 -0.00687343]
#  [-0.01421538 -0.01736906 -0.01376318  0.04694484  0.01677868 -0.03001793]
#  [ 0.01560605  0.01906825  0.01510962 -0.05153739 -0.01842012  0.03295454]
#  [-0.01042576 -0.01273871 -0.01009411  0.03443     0.01230572 -0.02201557]
#  [ 0.02348133  0.02869067  0.02273439 -0.07754472 -0.02771547  0.04958441]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.0148878  -0.01819066 -0.01441422  0.04916543  0.01757236 -0.03143786]
#  [-0.00326549 -0.00398994 -0.00316162  0.01078395  0.00385432 -0.00689558]
#  [-0.01426118 -0.01742502 -0.01380753  0.04709608  0.01683275 -0.03011465]
#  [ 0.01565633  0.01912969  0.0151583  -0.05170343 -0.01847947  0.03306072]
#  [-0.01045935 -0.01277976 -0.01012664  0.03454093  0.01234537 -0.02208651]
#  [ 0.023557    0.02878312  0.02280765 -0.07779456 -0.02780477  0.04974418]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484014 -0.01813243 -0.01436808  0.04900802  0.0175161  -0.03133721]
#  [-0.00325504 -0.00397717 -0.00315149  0.01074942  0.00384198 -0.0068735 ]
#  [-0.01421553 -0.01736924 -0.01376333  0.04694529  0.01677886 -0.03001824]
#  [ 0.01560621  0.01906845  0.01510978 -0.05153788 -0.01842031  0.03295488]
#  [-0.01042587 -0.01273885 -0.01009422  0.03443034  0.01230585 -0.0220158 ]
#  [ 0.02348158  0.02869097  0.02273463 -0.07754547 -0.02771576  0.04958492]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488766 -0.01819049 -0.01441409  0.04916493  0.01757219 -0.03143755]
#  [-0.00326546 -0.0039899  -0.00316159  0.01078384  0.00385429 -0.00689551]
#  [-0.01426105 -0.01742486 -0.0138074   0.0470956   0.01683259 -0.03011436]
#  [ 0.01565619  0.01912951  0.01515816 -0.0517029  -0.0184793   0.0330604 ]
#  [-0.01045925 -0.01277964 -0.01012654  0.03454058  0.01234526 -0.02208629]
#  [ 0.02355678  0.02878285  0.02280744 -0.07779376 -0.02780451  0.04974369]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.0148403  -0.01813262 -0.01436823  0.04900849  0.01751629 -0.03133752]
#  [-0.00325507 -0.00397721 -0.00315153  0.01074952  0.00384202 -0.00687357]
#  [-0.01421567 -0.01736942 -0.01376347  0.04694574  0.01677903 -0.03001854]
#  [ 0.01560637  0.01906865  0.01510994 -0.05153838 -0.0184205   0.03295521]
#  [-0.01042598 -0.01273898 -0.01009433  0.03443067  0.01230598 -0.02201602]
#  [ 0.02348183  0.02869127  0.02273487 -0.07754622 -0.02771605  0.04958542]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488753 -0.01819032 -0.01441395  0.04916443  0.01757203 -0.03143725]
#  [-0.00326543 -0.00398987 -0.00316156  0.01078373  0.00385425 -0.00689545]
#  [-0.01426092 -0.0174247  -0.01380728  0.04709512  0.01683243 -0.03011407]
#  [ 0.01565604  0.01912933  0.01515802 -0.05170237 -0.01847912  0.03306008]
#  [-0.01045916 -0.01277952 -0.01012645  0.03454023  0.01234514 -0.02208608]
#  [ 0.02355656  0.02878258  0.02280723 -0.07779297 -0.02780426  0.04974321]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484045 -0.0181328  -0.01436838  0.04900895  0.01751647 -0.03133783]
#  [-0.00325511 -0.00397725 -0.00315156  0.01074963  0.00384206 -0.00687364]
#  [-0.01421582 -0.0173696  -0.01376362  0.04694619  0.01677921 -0.03001884]
#  [ 0.01560654  0.01906885  0.01511009 -0.05153887 -0.01842069  0.03295554]
#  [-0.01042608 -0.01273911 -0.01009443  0.03443099  0.01230611 -0.02201624]
#  [ 0.02348207  0.02869157  0.02273511 -0.07754696 -0.02771634  0.04958591]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488739 -0.01819015 -0.01441382  0.04916394  0.01757187 -0.03143694]
#  [-0.0032654  -0.00398983 -0.00316153  0.01078362  0.00385421 -0.00689538]
#  [-0.01426078 -0.01742454 -0.01380715  0.04709465  0.01683228 -0.03011378]
#  [ 0.0156559   0.01912916  0.01515788 -0.05170185 -0.01847895  0.03305976]
#  [-0.01045906 -0.0127794  -0.01012636  0.03453988  0.01234503 -0.02208587]
#  [ 0.02355634  0.02878231  0.02280702 -0.07779219 -0.027804    0.04974273]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.0148406  -0.01813299 -0.01436853  0.04900942  0.01751665 -0.03133815]
#  [-0.00325514 -0.00397729 -0.00315159  0.01074973  0.0038421  -0.00687371]
#  [-0.01421597 -0.01736978 -0.01376376  0.04694663  0.01677938 -0.03001914]
#  [ 0.0156067   0.01906904  0.01511025 -0.05153936 -0.01842088  0.03295587]
#  [-0.01042619 -0.01273924 -0.01009454  0.03443132  0.01230623 -0.02201646]
#  [ 0.02348232  0.02869186  0.02273535 -0.07754769 -0.02771662  0.04958641]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488725 -0.01818999 -0.01441369  0.04916344  0.01757171 -0.03143664]
#  [-0.00326537 -0.00398979 -0.0031615   0.01078351  0.00385418 -0.00689531]
#  [-0.01426065 -0.01742438 -0.01380702  0.04709418  0.01683212 -0.03011349]
#  [ 0.01565575  0.01912898  0.01515775 -0.05170133 -0.01847878  0.03305945]
#  [-0.01045896 -0.01277928 -0.01012627  0.03453953  0.01234491 -0.02208566]
#  [ 0.02355613  0.02878205  0.02280681 -0.07779141 -0.02780374  0.04974226]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484076 -0.01813318 -0.01436867  0.04900988  0.01751683 -0.03133846]
#  [-0.00325517 -0.00397733 -0.00315163  0.01074983  0.00384214 -0.00687378]
#  [-0.01421612 -0.01736996 -0.0137639   0.04694707  0.01677955 -0.03001943]
#  [ 0.01560686  0.01906924  0.01511041 -0.05153984 -0.01842107  0.03295619]
#  [-0.0104263  -0.01273937 -0.01009464  0.03443164  0.01230636 -0.02201667]
#  [ 0.02348256  0.02869216  0.02273558 -0.07754842 -0.02771691  0.0495869 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488712 -0.01818982 -0.01441356  0.04916295  0.01757155 -0.03143634]
#  [-0.00326534 -0.00398976 -0.00316147  0.0107834   0.00385414 -0.00689525]
#  [-0.01426052 -0.01742422 -0.0138069   0.04709371  0.01683197 -0.0301132 ]
#  [ 0.01565561  0.0191288   0.01515761 -0.05170082 -0.01847861  0.03305913]
#  [-0.01045887 -0.01277917 -0.01012617  0.03453919  0.0123448  -0.02208545]
#  [ 0.02355591  0.02878178  0.0228066  -0.07779063 -0.02780349  0.04974178]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484091 -0.01813336 -0.01436882  0.04901034  0.01751701 -0.03133876]
#  [-0.00325521 -0.00397737 -0.00315166  0.01074993  0.00384218 -0.00687385]
#  [-0.01421626 -0.01737013 -0.01376404  0.04694751  0.01677972 -0.03001973]
#  [ 0.01560702  0.01906943  0.01511056 -0.05154032 -0.01842126  0.03295652]
#  [-0.01042641 -0.0127395  -0.01009474  0.03443197  0.01230648 -0.02201689]
#  [ 0.0234828   0.02869245  0.02273581 -0.07754914 -0.02771719  0.04958738]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488698 -0.01818965 -0.01441343  0.04916247  0.01757139 -0.03143605]
#  [-0.00326531 -0.00398972 -0.00316144  0.0107833   0.00385411 -0.00689518]
#  [-0.0142604  -0.01742406 -0.01380677  0.04709324  0.01683181 -0.03011292]
#  [ 0.01565547  0.01912863  0.01515747 -0.0517003  -0.01847845  0.03305882]
#  [-0.01045878 -0.01277905 -0.01012608  0.03453884  0.01234469 -0.02208524]
#  [ 0.0235557   0.02878152  0.0228064  -0.07778986 -0.02780324  0.04974132]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484106 -0.01813354 -0.01436897  0.04901079  0.01751718 -0.03133907]
#  [-0.00325524 -0.00397741 -0.00315169  0.01075003  0.00384222 -0.00687391]
#  [-0.01421641 -0.01737031 -0.01376418  0.04694795  0.01677989 -0.03002002]
#  [ 0.01560718  0.01906962  0.01511072 -0.0515408  -0.01842145  0.03295684]
#  [-0.01042651 -0.01273963 -0.01009485  0.03443229  0.01230661 -0.02201711]
#  [ 0.02348304  0.02869274  0.02273604 -0.07754986 -0.02771747  0.04958787]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488685 -0.01818949 -0.0144133   0.04916198  0.01757123 -0.03143575]
#  [-0.00326528 -0.00398968 -0.00316141  0.01078319  0.00385407 -0.00689512]
#  [-0.01426027 -0.0174239  -0.01380665  0.04709277  0.01683166 -0.03011264]
#  [ 0.01565533  0.01912846  0.01515734 -0.0516998  -0.01847828  0.03305851]
#  [-0.01045868 -0.01277893 -0.01012599  0.0345385   0.01234458 -0.02208503]
#  [ 0.02355549  0.02878126  0.02280619 -0.07778909 -0.02780299  0.04974085]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484121 -0.01813373 -0.01436911  0.04901124  0.01751736 -0.03133937]
#  [-0.00325527 -0.00397745 -0.00315172  0.01075013  0.00384226 -0.00687398]
#  [-0.01421655 -0.01737048 -0.01376432  0.04694838  0.01678006 -0.03002031]
#  [ 0.01560734  0.01906982  0.01511087 -0.05154128 -0.01842163  0.03295716]
#  [-0.01042662 -0.01273976 -0.01009495  0.0344326   0.01230673 -0.02201732]
#  [ 0.02348328  0.02869303  0.02273627 -0.07755058 -0.02771775  0.04958835]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01488672 -0.01818933 -0.01441317  0.0491615   0.01757107 -0.03143546]
#  [-0.00326525 -0.00398965 -0.00316139  0.01078309  0.00385404 -0.00689506]
#  [-0.01426014 -0.01742375 -0.01380653  0.04709231  0.01683151 -0.03011236]
#  [ 0.01565519  0.01912829  0.0151572  -0.05169929 -0.01847811  0.0330582 ]
#  [-0.01045859 -0.01277882 -0.0101259   0.03453816  0.01234447 -0.02208482]
#  [ 0.02355528  0.028781    0.02280599 -0.07778833 -0.02780274  0.04974039]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484136 -0.01813391 -0.01436926  0.04901169  0.01751753 -0.03133968]
#  [-0.0032553  -0.00397749 -0.00315175  0.01075023  0.0038423  -0.00687405]
#  [-0.01421669 -0.01737066 -0.01376446  0.04694881  0.01678023 -0.0300206 ]
#  [ 0.01560749  0.01907001  0.01511102 -0.05154175 -0.01842182  0.03295748]
#  [-0.01042672 -0.01273989 -0.01009505  0.03443292  0.01230686 -0.02201753]
#  [ 0.02348351  0.02869331  0.0227365  -0.07755129 -0.02771803  0.04958883]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-3cbd6e5bedb4> in <module>()
#      31
#      32
# ---> 33 learnBPCA(data, epsilon=1, maxIterations=1000)
#
# <ipython-input-150-3cbd6e5bedb4> in learnBPCA(D, epsilon, maxIterations)
#      14     while(Ldelta > epsilon and iteration < maxIterations):
#      15
# ---> 16         bPCA.fit(D)
#      17
#      18         L = bPCA.L(D)
#
# <ipython-input-142-615793d598ac> in fit(self, X)
#     141
#     142         self.update_w(X)
# --> 143         self.update_tau(X)
#     144         self.update_mu(X)
#     145         self.update_alpha()
#
# <ipython-input-142-615793d598ac> in update_tau(self, D)
#     123             summed += np.dot(tn.T, tn) + exp_mutmu
#     124             summed += np.trace(np.dot(exp_WtW, exp_xxt))
# --> 125             summed += 2.0 * np.dot(np.dot(self.mean_mu.T, self.means_w), exp_xn)
#     126             summed -= 2.0 * np.dot(np.dot(tn.T, self.means_w), exp_xn)
#     127             summed -= 2.0 * np.dot(tn.T, self.mean_mu)
#
# KeyboardInterrupt:
# [[-0.01488659 -0.01818916 -0.01441304  0.04916102  0.01757091 -0.03143517]
#  [-0.00326522 -0.00398961 -0.00316136  0.01078298  0.00385401 -0.00689499]
#  [-0.01426002 -0.01742359 -0.01380641  0.04709185  0.01683136 -0.03011208]
#  [ 0.01565505  0.01912812  0.01515707 -0.05169879 -0.01847795  0.0330579 ]
#  [-0.0104585  -0.01277871 -0.01012581  0.03453783  0.01234436 -0.02208462]
#  [ 0.02355507  0.02878075  0.02280579 -0.07778757 -0.02780249  0.04973993]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01
#
#  w final:
# [[-0.01484151 -0.01813409 -0.0143694   0.04901214  0.01751771 -0.03133998]
#  [-0.00325534 -0.00397753 -0.00315179  0.01075032  0.00384234 -0.00687411]
#  [-0.01421684 -0.01737083 -0.0137646   0.04694924  0.0167804  -0.03002089]
#  [ 0.01560765  0.0190702   0.01511117 -0.05154222 -0.018422    0.03295779]
#  [-0.01042683 -0.01274001 -0.01009515  0.03443323  0.01230698 -0.02201774]
#  [ 0.02348375  0.0286936   0.02273673 -0.077552   -0.0277183   0.0495893 ]]
# 0
# dimensions data: (6, 100)
# a alpha tilde = 3.01

# %% [markdown]
# ### 1. The Q-distribution (5 points)
#
# In variational Bayes, we introduce a distribution $Q(\Theta)$ over parameters / latent variables in order to make inference tractable. We can think of $Q$ as being an approximation of a certain distribution. What function does $Q$ approximate, $p(D|\Theta)$, $p(\Theta|D)$, $p(D, \Theta)$, $p(\Theta)$, or $p(D)$, and how do you see that?

# %% [markdown]
# The function $Q$ approximates the function that is the posterior distribution, $p(\Theta | D) $.
#
# The posterior $P(\Theta | D)$ is given by multiplying the likelihood by the prior and then normalizing:
#
# \begin{align}
# P(\Theta | D) &= \dfrac{P(D | \Theta)P( \Theta)}{P(D)} \\
#               &= \dfrac{P(D | \Theta)P( \Theta)}{\int P(D | \Theta)P(\Theta) \hspace{1mm} d\Theta}
# \end{align}
#
# Why is this useful?
# For Maximum a Posteriori (MAP) learning, we could use the posterior to get a point estimate of the parameters:
#
# \begin{align}
# \widetilde{\Theta}_{\text{MAP}}(D)&= \arg\max_{\Theta} P(\Theta | D) \\
#             & \propto {P(D | \Theta)P( \Theta)}
# \end{align}
#
# So for MAP learning the normalization (and therefore integration) is not needed. Like Maximum likelihood estimation (MLE) learning, MAP learning learns a point estimate of our parameters.
#
# In the Bayesian framework no fixed parameter setting is chosen. The posterior is used to obtain a predictive density (also called the posterior predictive distribution) for a new data point $t^{*}$ with:
#
# \begin{align}
# P(t^{*} | D) &= \int P(t^{*} | \Theta) P(\Theta | D) \hspace{2mm} d\Theta
# \end{align}
#
# This means that in the Bayesian learning framework we consider all possible parametrizations of our models by incorporating the posterior this way. Each of these is weighted by the evidence for them in $D$.
# (Note that when predicting, we also return a probability distribution as prediction for $t^{*}$.
# Retaining all possible parametrizations is in this case of Principal Component Analysis) particularly advantageous for automatically determining an adequate number of principal components given $D$.
#
# Note that we need to integrate over all possible parametrizations for this. In practice this can quickly become infeasible for models with many parameters; when using a mixture of models; or when the prior distribution is not of the same functional form as the likelihood distribution. Therefore we use a ''simpler'' distribution $Q(\Theta)$ to approximate $P(\Theta|D)$.

# %% [markdown]
# ### 2. The mean-field approximation (15 points)
#
# Equation 13 from [Bishop99] is a very powerful result: assuming only that $Q(\Theta)$ factorizes in a certain way (no assumptions on the functional form of the factors $Q_i$!), we get a set of coupled equations for the $Q_i$.
#
# However, the expression given in eq. 13 for Q_i contains a small mistake. Starting with the expression for the lower bound $\mathcal{L}(Q)$, derive the correct expression (and include your derivation). You can proceed as follows: first, substitute the factorization of $Q$ (eq. 12) into the definition of $\mathcal{L}(Q)$ and separate $\mathcal{L}(Q)$ into $Q_i$-dependent and $Q_i$-independent terms. At this point, you should be able to spot the expectations $\langle\cdot\rangle_{k \neq i}$ over the other $Q$-distributions that appear in Bishop's solution (eq. 13). Now, keeping all $Q_k, k \neq i$ fixed, maximize the expression with respect to $Q_i$. You should be able to spot the form of the optimal $ln Q_i$, from which $Q_i$ can easily be obtained.

# %% [markdown]
# It is given that the lower bound is
#
# $$
# \begin{align}
# \mathcal{L}(Q) =& \int Q(\Theta) \log \dfrac{P(D, \Theta)}{Q(\Theta)}
#                 \hspace{3mm} d \Theta  \\
# \end{align}
# $$
#
# And the factorization is
#
# \begin{equation}
# Q(\Theta)= \prod_{k} Q_k(\Theta_k)
# \end{equation}
#
# Plugging in the factorization into the lower bound, we get
#
# \begin{align}
# \mathcal{L}(Q) =&  \int
#                      \prod_{k} Q_k( \Theta_k)
#                      \left[
#                          \log P(D,\Theta) - \log \left( \prod_k Q_k(\Theta_k) \right)
#                      \right]
#                  \hspace{3mm} d \Theta  \\
#               =& \int
#               \prod_{k} Q_k( \Theta_k)
#                      \left[
#                          \log P(D,\Theta) - \sum_k \log Q_k(\Theta_k)
#                      \right]
#                   \hspace{3mm} d \Theta
# \end{align}
#
# By denoting a specific factor $Q_i$ separately we arrive at
#
# \begin{align}
# \mathcal{L}(Q) =& \int Q_i( \Theta_i) \prod_{k \neq i} Q_k( \Theta_k)
#                 \left[ \log P(D, \Theta) - \log \left( \prod_{j \neq i}  Q_j(\Theta_j) \right) - \log Q_i (\Theta_i) \right]
#                 \hspace{3mm} d \Theta
# \end{align}
#
# By taking the integral of $Q_i$ apart from those for $\{Q_1, \dots ,Q_{i-1},Q_{i+1}, \dots ,Q_M \}$, we get
#
# \begin{align}
# \mathcal{L}(Q) =&
#     \int Q_i(\Theta_i)
#         \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k) \log P(D, \Theta)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#     \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k)
#             \log \left( \prod_{j \neq i} Q_j(\Theta_j) \right)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}  \hspace{3mm} - \\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#             \int
#              \prod_{k \neq i} Q_k( \Theta_k)
#              \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}
# \end{align}

# %% [markdown]
# Now, when we keep the $Q_k \neq Q_{i}$ fixed the following happens, the integral over $\Theta_{\setminus i}$  in the third row of the equation for $\mathcal{L}(Q)$ will become 1, because all $Q_n(\Theta_n)$ are probability distributions.
#
# \begin{align}
# \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#             \int
#              \prod_{k \neq i} Q_k( \Theta_k)
#              \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}
#         =&
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#         \prod_{k \neq i}
#             \int
#               Q_k( \Theta_k)
#              \hspace{3mm} d \Theta_{k}
#         \right]
#         \hspace{3mm} d \Theta_{i} \\
#      =&
#       \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \left[
#         \prod_{k \neq i}
#             1
#         \right]
#         \hspace{3mm} d \Theta_{i}
# \end{align}
#
# So we can rewrite the equation as
#
# \begin{align}
# \mathcal{L}(Q)  =&
#     \int Q_i(\Theta_i)
#         \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k) \log P(D, \Theta)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#     \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k)
#             \log \left( \prod_{j \neq i} Q_j(\Theta_j) \right)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i}  \hspace{3mm} - \\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \hspace{3mm} d \Theta_{i}
# \end{align}
#
#
# Furthermore, when we keep the $Q_k \neq Q_{i}$ fixed, the $\Theta_{\setminus i}$ integral in the second row of the equation for  $\mathcal{L}(Q)$ will become a constant. We know that $\int Q_i(\Theta_i)  d\Theta_{i}$ should be 1 because $Q_i$ is a probability distribution. So the whole second row can be viewed as a constant.
#
#
# \begin{align}
# \mathcal{L}(Q)  =&
#     \int Q_i(\Theta_i)
#         \left[
#             \int  \prod_{k \neq i} Q_k( \Theta_k) \log P(D, \Theta)
#             \hspace{3mm} d \Theta_{\setminus i}
#         \right]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \hspace{3mm} d \Theta_{i}  \hspace{1mm} + \text{const}
# \end{align}

# %% [markdown]
# Note that the integral over $\Theta_{\setminus i}$  in the  first line in $\mathcal{L}(Q)$ could be rewritten as an expectation :
#
# \begin{align}
# \mathcal{L}(Q)  =&
#     \int Q_i(\Theta_i) \cdot
#         \mathbb{E}_{[k \neq i]}[ \log P(D, \Theta)]
#         \hspace{3mm} d \Theta_{i} \hspace{3mm} -\\
# &
#     \int Q_i(\Theta_i)
#         \log Q_i (\Theta_i)
#         \hspace{3mm} d \Theta_{i}  \hspace{1mm} + \text{const}
# \end{align}
#
# Where $\mathbb{E}_{[k \neq i]}$ denotes this expected value is with respect to the $Q$ distributions over all variables $\Theta_k \neq \Theta_i$.
#
#
# We can define $\mathbb{E}_{[k \neq i]}[ \log P(D, \Theta)]$ as $\log \widetilde{P}(D, \Theta_i)$.
#
# Intuitively it makes sense to see  $\log \widetilde{P}(D, \Theta_i)$, the joint probability of that parameter and the data, as the expectation of $\log P(D, \Theta)$ under all $\Theta_k$ that are not $\Theta_i$ , i.e., to not marginalize out  $\Theta_i$ in $\log P(D, \Theta)$.
# It is here particularly useful to be able to rewrite the above equation as:
#
# \begin{align}
# \mathcal{L}(Q)  =&  \int Q_i(\Theta_i) \log \widetilde{P}(D, \Theta_i) -  \int Q_i(\Theta_i) \log Q_i(\Theta_i) \\
#                 =& \int Q_i(\Theta_i) \log \dfrac{\widetilde{P}(D , \Theta_i)}{ Q_i(\Theta_i)} \\
#                 =& - \text{KL} \left(Q_i(\Theta_i) || \widetilde{P}(D, \Theta_i) \right)
# \end{align}
#
# Recall we wanted to maximize the lower bound function $\mathcal{L}(Q)$. We see that this negative KL-divergence will be maximal when
#
# \begin{align}
#  Q_i(\Theta_i) &= \widetilde{P}(D, \Theta_i)  \\
#  \log  Q_i(\Theta_i) &= \log \widetilde{P}(D, \Theta_i)  \\
#                      &= \mathbb{E}_{[k \neq i]}[\log P(D, \Theta)]\\
#  Q_i(\Theta_i)      &= \exp \left( \mathbb{E}_{[k \neq i]} [\log P(D, \Theta)] \right)
# \end{align}
#
# So in line with Bishop (except a subscript mismatch on his side), accounting for normalization (marginalizing over all $\Theta_{\setminus i}$) we get that the optimal value for $Q_i$ is
#
# \begin{align}
#  Q_i^{*}(\Theta_i)      &= \dfrac{\exp ( \mathbb{E}_{[k \neq i]} [\log P(D, \Theta)] )   }
#                       {\int \exp ( \mathbb{E}_{[k \neq i]} [\log P(D, \Theta)] ) \hspace{2mm} d\Theta_i  }
# \end{align}

# %% [markdown]
# ### 3. The log-probability (10 points)
#
# Write down the log-prob of data and parameters, $\ln p(\mathbf{X}, \mathbf{Z}, \mathbf{W}, \mathbf{\alpha}, \tau, \mathbf{\mu})$, in full detail (where $\mathbf{X}$ are observed, $\mathbf{Z}$ is latent; this is different from [Bishop99] who uses $\mathbf{T}$ and $\mathbf{X}$ respectively, but $\mathbf{X}$ and $\mathbf{Z}$ are consistent with the PRML book and are more common nowadays). Could we use this to assess the convergence of the variational Bayesian PCA algorithm? If yes, how? If no, why not?

# %% [markdown]
# The log-probability of the data and parameters is defined as:
# $$
# \begin{align}
# \ln p ( X, Z, W, \alpha, \tau, \mu) =&
# \ln \left(  \prod_{n=1}^N p(x_n| z_n, W, \mu, \tau)p(Z)p(W|\alpha)p(\alpha)p(\mu)p(\tau) \right) \\
# =& \ln \left( \prod_{n=1}^N \left[ \left( \frac{\tau}{2 \pi} \right) ^{D/2} \exp \left( - \frac{\tau}{2} \parallel x_t-Wz_n-\mu \parallel ^2  \right) \right]
# \prod_{n=1}^N \left[  \left( \frac{1}{2 \pi} \right)^{q/2} \exp \left( - \frac{1}{2} z_n^\top z_n \right) \right] \\
# \prod_{i=1}^q \left[ \left( \frac{\alpha_i}{2 \pi} \right)^{D/2} \exp \left( -\frac{\alpha_i}{2}  w_i^\top w_i \right) \right]
# \prod_{i=1}^q \left[ \frac{1}{\Gamma(a_\alpha)} b_\alpha^{a_\alpha} \alpha_i^{a_\alpha-1} e^{-b_\alpha \: \alpha_i} \right]\\
# \left[ \left(\frac{ \beta}{2\pi} \right)^{D/2} \exp \left( - \frac{\beta}{2} \mu^\top \mu \right) \right]
# \left[ \frac{1}{\Gamma(c_\tau)} d_\tau^{c_\tau} \tau^{c_\tau-1} e^{-d_\tau \: \tau} \right] \right)
# \\
# =& \frac{ND}{2} \ln \frac{\tau}{2 \pi} + \sum_{n=1}^N \left[ - \frac{\tau}{2} \parallel x_n-Wz_n-\mu \parallel ^2 \right]
# + \frac{Nq}{2} \ln \frac{1}{2 \pi} + \sum_{n=1}^N \left[ - \frac{1}{2} z_n^\top z_n \right] \\
# &+ \sum_{i=1}^q \left[ \frac{D}{2} \ln \frac{\alpha_i}{2 \pi} \right] + \sum_{i=1}^q \left[ - \frac{\alpha_i}{2} w_i^\top w_i \right]
# + \: q \ln \frac{ b_\alpha^{a_\alpha}}{\Gamma(a_\alpha)} + \sum_{i=1}^q \left[ (a_\alpha -1) \ln \alpha_i - b_\alpha \alpha_i \right] \\
# &+ \frac{D}{2} \ln \frac{\beta}{2 \pi} - \frac{\beta}{2} \mu^\top\mu - \ln \Gamma(c_\tau) + \ln d_\tau^{c_\tau} + (c_\tau-1)\ln \tau - d_\tau \tau
# \end{align}
# $$

# %% [markdown]
# Bayesian learning results in a posterior distribution over the parameters. If we wish to use $\ln P(\Theta,D)$ to assess convergence we have no choice but to use some point estimate of the parameters from the approximated posterior $Q$ to evaluate  $\ln P(\Theta,D)$ (we cannot plug in the distribution). However, we consider convergence as $Q$ being as similar to the real posterior $P(\Theta|D)$ as possible. There is no guarantee that if $Q$ becomes more similar to $P(\Theta|D)$, that the used point estimate of $Q$ results in a higher value when evaluating $\ln P(\Theta,D)$. Therefore $\ln P(\Theta,D)$ is not a suitable option to assess convergence.

# %% [markdown]
# ### 4. The lower bound $\mathcal{L}(Q)$ (25 points)
#
# Derive an expression for the lower bound $\mathcal{L}(Q)$ of the log-prob $\ln p(X)$ for Bayesian PCA, making use of the factorization (eq. 12) and the form of the Q-distributions (eq. 16-20) as listed in [Bishop99]. Show your steps. Implement this function.
#
# The following result may be useful:
#
# For $x \sim \Gamma(a,b)$, we have $\langle \ln x\rangle = \ln b + \psi(a)$, where $\psi(a) = \frac{\Gamma'(a)}{\Gamma(a)}$ is the digamma function (which is implemented in numpy.special).

# %% [markdown]
# \begin{align}
# \mathcal{L}(Q) =& \int Q(\Theta) \ln \dfrac{P(D,\Theta)}{Q(\Theta)} \hspace{2mm} d \Theta\\
#                 =& \int Q(\Theta) \ln P(D,\Theta) \hspace{2mm} d \Theta  - \int Q(\Theta) \ln Q(\Theta)  \hspace{2mm} d \Theta\\
#                 =& \mathbb{E}_Q[ \ln P(D,\Theta)] - \mathbb{E}_q[\ln Q(\Theta)]\\
#                =& \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N} (x_n | m_x^{(n)} \Sigma_x) \right) \right]
#                 + \mathbb{E}_Q \left[ \ln P(X) \right ] + \mathbb{E}_Q \left[\ln  P(W | \alpha ) \right]
#                 + \mathbb{E}_Q \left[ \ln P(\alpha) \right] + \mathbb{E}_Q \left[ \ln P(\mu) \right]
#                 + \mathbb{E}_Q \left[ \ln P(\tau) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln Q(X) \right] - \mathbb{E}_Q \left[ \ln Q(W) \right] - \mathbb{E}_Q \left[ Q(\alpha) \right] - \mathbb{E}_Q \left[ \ln Q(\mu) \right] - \mathbb{E}_Q \left[ \ln \left( Q(\tau) \right) \right]\\
#                 =& \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N}({t}|{W} {x}_i + \mu , \sigma^2 I_d) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N}(x|0, I_q) \right) \right]              \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \prod_{i=1}^{q} (\dfrac{\alpha_i}{2 \pi})^{d/2}  \exp( - \dfrac{1}{2} \alpha_i ||w_i||^2 ) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \prod_{i=1}^{q} \Gamma ( \alpha_i| a_{\alpha}, b_{\alpha}) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \mathcal{N}(\mu|0, \beta^{-1} I) \right) \right] \\
#                 & + \mathbb{E}_Q \left[ \ln \left( \Gamma(\tau|c_\tau, d_\tau ) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \prod_{n=1}^{N} \mathcal{N}(x_n| m_x^{(n)}, \Sigma_x) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \prod_{k=1}^{d}  \mathcal{N}(\widetilde{w}_k | m_w^{(k)}, \Sigma_w) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \prod_{i=1}^{q} \Gamma(\alpha_i| \widetilde{a}_\alpha, \widetilde{b}_{\alpha i} ) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \mathcal{N}(\mu | m_\mu, \Sigma_\mu) \right) \right] \\
#                 & - \mathbb{E}_Q \left[ \ln \left( \Gamma(\tau | \widetilde{a}_\tau, \widetilde{b}_\tau ) \right) \right]
# \end{align}

# %% [markdown]
# ### 5. Optimize variational parameters (50 points)
# Implement the update equations for the Q-distributions, in the __update_XXX methods. Each update function should re-estimate the variational parameters of the Q-distribution corresponding to one group of variables (i.e. either $Z$, $\mu$, $W$, $\alpha$ or $\tau$).

# %% [markdown]
# ### 6. Learning algorithm (10 points)
# Implement the learning algorithm described in [Bishop99], i.e. iteratively optimize each of the Q-distributions holding the others fixed.
#
# What would be a good way to track convergence of the algorithm? Implement your suggestion.
#
# Test the algorithm on some test data drawn from a Gaussian with different variances in orthogonal directions.

# %% [markdown]
# We created a set of orthonormal basis vectors by using Matlab code from <a href="http://www.mathworks.com/matlabcentral/fileexchange/18973-create-orthonormal-vectors">[Price 2008]</a>.

# %%
# matrix with orthonormal vectors
A = np.array([ [0.4246,-0.1753,-0.1466,-0.0956,0.7864,0.3741]
                ,[0.5199,0.3483,0.2280,-0.4751,-0.4102,0.4031]
                ,[-0.2212,-0.7183,-0.2838,-0.2656,-0.3263,0.4213]
                ,[-0.5600,0.0724,0.6716,-0.1030,0.2397,0.4025]
                ,[0.2692,-0.1393,0.2114,0.8147,-0.2223,0.3876]
                ,[-0.3382,0.5544,-0.5918,0.1422,-0.0037,0.4558]])

# eigenvalues on a diagonal matrix representing the magnitude of the variance
L = np.diag( [7,6,5,4,1,1])

# Covariance matrix generated based on A and L
covariance = np.dot(np.dot(A, L) , A.T)
means = [2,2,2,2,2,2]

dims = 6
N = 1000

data = numpy.random.multivariate_normal(means, covariance, (N)).T

#print 'Plot of the first three dimensions of the data'
#plot_data(data)

bay_pca = BayesianPCA(dims,N)
#bay_pca.fit(data, 300)

# %% [markdown]
# ### 7. PCA Representation of MNIST (10 points)
#
# Download the MNIST dataset from here http://deeplearning.net/tutorial/gettingstarted.html (the page contains python code for loading the data). Run your algorithm on (part of) this dataset, and visualize the results.
